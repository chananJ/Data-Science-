# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import random
from datetime import datetime

# %%
# %matplotlib inline

# %%
df_sheet_all = pd.read_excel('C:\\Users\\chana\\Desktop\\Files\\FirstNames.xlsx', sheet_name=None)
#create headers:
df_jews_M=df_sheet_all['יהודים'][11:]
df_jews_M.columns = df_jews_M.iloc[0]
df_jews_M=df_jews_M[1:]
df_jews_M.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
#headers=list(df_jews_M.columns.values)
#this is source of list
#headers=list(df_jews_M.columns.values)
#headers=['name','total','sex','religion',1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,
#1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,
#1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,
#1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
df_jews_M.insert(2,'מגזר','יהודי')
df_jews_M.insert(3,'מין','זכר')
df_jews_M
# Out:
# 11      שם פרטי  סה"כ   מגזר  מין 1948 1949 1950 1951 1952 1953  ... 2012  \
# 12          אבא   179  יהודי  זכר    .    6   ..   ..    8   ..  ...   ..
# 13          אבי  9047  יהודי  זכר   34   49   53   79   92   80  ...    9
# 14    אבי-אברהם    29  יהודי  זכר    .    .    .    .    .    .  ...    .
# 15       אביאור   523  יהודי  זכר    .    .    .    .    .    .  ...   11
# 16        אביאל  5734  יהודי  זכר   ..   ..   ..   ..   ..   ..  ...  161
# ...         ...   ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1049      תימור   129  יהודי  זכר    .    .    .    .    .    .  ...    5
# 1050        תלם    67  יהודי  זכר    .    .    .    .    .    .  ...   ..
# 1051         תם   590  יהודי  זכר    .    .    .    .    .    .  ...   ..
# 1052       תמיר  6247  יהודי  זכר    .   ..    .    5   ..    9  ...   65
# 1053        תמר   107  יהודי  זכר    .    .    .    .    .    .  ...   ..
#
# 11   2013 2014 2015 2016 2017 2018 2019 2020 2021
# ...

# %%
#each data set define in row sex and religion:

# %%
#jews female
df_jews_F=df_sheet_all['יהודיות'][11:]
df_jews_F.columns = df_jews_F.iloc[0]
df_jews_F=df_jews_F[1:]
df_jews_F.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_jews_F.insert(2,'מגזר','יהודי')
df_jews_F.insert(3,'מין','נקבה')
df_jews_F
# Out:
# 11   שם פרטי   סה"כ   מגזר   מין 1948 1949 1950 1951 1952 1953  ... 2012 2013  \
# 12     אבגיל     54  יהודי  נקבה    .    .    .    .    .    .  ...   ..   ..
# 13      אביב   4421  יהודי  נקבה    .    .    .    .   ..    .  ...  150  125
# 14     אביבה   5401  יהודי  נקבה   44   76  113  159  158  168  ...   12    9
# 15    אביבית   1979  יהודי  נקבה    .   ..    .   ..    6   ..  ...   ..   ..
# 16    אביגיל  19873  יהודי  נקבה   14   16   20   23   26   29  ...  827  927
# ...      ...    ...    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1490   תפארת   1339  יהודי  נקבה    .    .    .   ..    .    .  ...   50   39
# 1491    תקוה   1933  יהודי  נקבה   15   13   35  112  138  162  ...   ..    6
# 1492    תרזה    100  יהודי  נקבה    .   ..   ..   ..   ..   ..  ...   ..    .
# 1493    תרין     71  יהודי  נקבה    .    .    .    .    .    .  ...    7   ..
# 1494    תרצה   1139  יהודי  נקבה   10   15   27   16   13   12  ...   11   13
#
# ...

# %%
#Male Muslim
df_muslim_M=df_sheet_all['מוסלמים'][11:]
df_muslim_M.columns = df_muslim_M.iloc[0]
df_muslim_M=df_muslim_M[1:]
df_muslim_M.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_muslim_M.insert(2,'מגזר','מוסלמי')
df_muslim_M.insert(3,'מין','זכר')
df_muslim_M
# Out:
# 11   שם פרטי   סה"כ    מגזר  מין 1948 1949 1950 1951 1952 1953  ... 2012 2013  \
# 12      אאוס     81  מוסלמי  זכר    .    .    .    .    .    .  ...   ..   ..
# 13   אבראהים  17114  מוסלמי  זכר   31   40   61   71   84   93  ...  376  347
# 14     אברהם     93  מוסלמי  זכר    .    .    .    .    .   ..  ...   ..    5
# 15      אדהם   2479  מוסלמי  זכר    .    .    .    .   ..    .  ...   35   38
# 16     אדיאן     30  מוסלמי  זכר    .    .    .    .    .    .  ...   ..   ..
# ..       ...    ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 729      תים    398  מוסלמי  זכר    .    .    .    .    .    .  ...   10   22
# 730    תימור     69  מוסלמי  זכר    .    .    .    .    .    .  ...   ..    .
# 731     תמים    402  מוסלמי  זכר   ..    .   ..   ..   ..   ..  ...   ..    6
# 732     תמיר    269  מוסלמי  זכר    .    .    .    .    .    .  ...   12    8
# 733      תקי     64  מוסלמי  זכר    .    .    .   ..    .    .  ...   ..   ..
#
# ...

# %%
#Muslim Female
df_muslim_f=df_sheet_all['מוסלמיות'][11:]
df_muslim_f.columns = df_muslim_f.iloc[0]
df_muslim_f=df_muslim_f[1:]
df_muslim_f.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_muslim_f.insert(2,'מגזר','מוסלמי')
df_muslim_f.insert(3,'מין','נקבה')
df_muslim_f
# Out:
# 11     שם פרטי סה"כ    מגזר   מין 1948 1949 1950 1951 1952 1953  ... 2012  \
# 12     אבטיסאם   20  מוסלמי  נקבה    .    .    .    .    .    .  ...    .
# 13       אבראר  590  מוסלמי  נקבה    .    .    .    .    .    .  ...   13
# 14        אברר   48  מוסלמי  נקבה    .    .    .    .    .    .  ...    .
# 15      אבתהאל  189  מוסלמי  נקבה    .    .    .    .    .    .  ...   ..
# 16    אבתיהאג'   36  מוסלמי  נקבה    .    .    .    .   ..    .  ...    .
# ...        ...  ...     ...   ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1508       תרא   43  מוסלמי  נקבה    .    .    .    .    .    .  ...    .
# 1509      תראא  126  מוסלמי  נקבה    .    .    .    .    .    .  ...   ..
# 1510      תריא   59  מוסלמי  נקבה    .    .    .    .   ..   ..  ...    .
# 1511     תרנים   45  מוסלמי  נקבה    .    .    .    .    .    .  ...   ..
# 1512     תרתיל  230  מוסלמי  נקבה    .    .    .    .    .    .  ...    8
#
# 11   2013 2014 2015 2016 2017 2018 2019 2020 2021
# ...

# %%
#christan male
df_christan_M=df_sheet_all['נוצרים'][11:]
df_christan_M.columns = df_christan_M.iloc[0]
df_christan_M=df_christan_M[1:]
df_christan_M.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_christan_M.insert(2,'מגזר','נוצרי')
df_christan_M.insert(3,'מין','זכר')
df_christan_M
# Out:
# 11   שם פרטי סה"כ   מגזר  מין 1948 1949 1950 1951 1952 1953  ... 2012 2013  \
# 12   'ג'ורג'  470  נוצרי  זכר   ..   ..    6   ..    8   ..  ...    8    9
# 13   אבראהים  757  נוצרי  זכר    8    6    5   10   10    8  ...    8    6
# 14      אדהם  130  נוצרי  זכר    .    .    .    .    .    .  ...    .    .
# 15     אדואר  179  נוצרי  זכר   ..   ..    5    8    5   ..  ...    .   ..
# 16    אדוארד  185  נוצרי  זכר   ..    .   ..   ..   ..   ..  ...   ..   ..
# ..       ...  ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 258     שריף   45  נוצרי  זכר    .    .    .    .    .    .  ...    .    .
# 259   תאופיק  301  נוצרי  זכר   ..   ..   ..   ..   ..   ..  ...   ..   ..
# 260     תאמר  256  נוצרי  זכר    .    .    .    .    .    .  ...   ..   ..
# 261    תומאס   82  נוצרי  זכר    .    .    .    .    .   ..  ...   ..   ..
# 262     תיים   34  נוצרי  זכר    .    .    .    .    .    .  ...    .   ..
#
# 11  2014 2015 2016 2017 2018 2019 2020 2021
# ...

# %%
#christan female
df_christan_F=df_sheet_all['נוצריות'][11:]
df_christan_F.columns = df_christan_F.iloc[0]
df_christan_F=df_christan_F[1:]
df_christan_F.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_christan_F.insert(2,'מגזר','נוצרי')
df_christan_F.insert(3,'מין','נקבה')
df_christan_F
# Out:
# 11   שם פרטי סה"כ   מגזר   מין 1948 1949 1950 1951 1952 1953  ... 2012 2013  \
# 12   אבתיסאם   89  נוצרי  נקבה   ..   ..    .   ..   ..    .  ...    .    .
# 13       אדל   33  נוצרי  נקבה    .    .    .    .    .    .  ...   ..   ..
# 14      אווה   64  נוצרי  נקבה    .    .    .    .    .   ..  ...   ..   ..
# 15    אומימה   82  נוצרי  נקבה    .    .    .    .    .    .  ...    .   ..
# 16    אח'לאס   57  נוצרי  נקבה    .   ..   ..   ..   ..    .  ...    .    .
# ..       ...  ...    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 368    תולין   98  נוצרי  נקבה    .    .    .    .    .    .  ...    8   13
# 369      תיא  151  נוצרי  נקבה    .    .    .    .    .    .  ...    8    8
# 370    תיריז  123  נוצרי  נקבה    5   ..    5   ..    6   ..  ...    .    .
# 371     תלין   38  נוצרי  נקבה    .    .    .    .    .    .  ...   ..   ..
# 372     תמאם   65  נוצרי  נקבה   ..   ..   ..   ..    5   ..  ...   ..    .
#
# 11  2014 2015 2016 2017 2018 2019 2020 2021
# ...

# %%
#druze Male
df_druze_M=df_sheet_all['דרוזים'][11:]
df_druze_M.columns = df_druze_M.iloc[0]
df_druze_M=df_druze_M[1:]
df_druze_M.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_druze_M.insert(2,'מגזר','דרוזי')
df_druze_M.insert(3,'מין','זכר')
df_druze_M
# Out:
# 11  שם פרטי  סה"כ   מגזר  מין 1948 1949 1950 1951 1952 1953  ... 2012 2013  \
# 12     אדהם   493  דרוזי  זכר    .    .    .    .    .    .  ...   ..   ..
# 13     אדיב   153  דרוזי  זכר    .    .   ..   ..   ..   ..  ...    .   ..
# 14     אדיר   166  דרוזי  זכר    .    .    .    .    .    .  ...    9   ..
# 15      אדם  1233  דרוזי  זכר    .    .    .    .    .    .  ...   43   38
# 16     אווס    87  דרוזי  זכר    .    .    .    .    .    .  ...    8    7
# ..      ...   ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 294  תיימור   139  דרוזי  זכר    .    .    .    .    .    .  ...    .    .
# 295     תים    59  דרוזי  זכר    .    .    .    .    .    .  ...   ..   ..
# 296   תימור   183  דרוזי  זכר    .    .    .    .    .    .  ...   ..   ..
# 297   תיראן    76  דרוזי  זכר    .    .    .    .    .    .  ...   ..   ..
# 298    תמיר   434  דרוזי  זכר    .    .    .    .    .    .  ...    8    6
#
# 11  2014 2015 2016 2017 2018 2019 2020 2021
# ...

# %%
#druze feMale
df_druze_F=df_sheet_all['דרוזיות'][11:]
df_druze_F.columns = df_druze_F.iloc[0]
df_druze_F=df_druze_F[1:]
df_druze_F.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_druze_F.insert(2,'מגזר','דרוזי')
df_druze_F.insert(3,'מין','נקבה')
df_druze_F
# Out:
# 11   שם פרטי סה"כ   מגזר   מין 1948 1949 1950 1951 1952 1953  ... 2012 2013  \
# 12   אבתיסאם  121  דרוזי  נקבה   ..    .   ..   ..    .   ..  ...    .   ..
# 13       אדל   36  דרוזי  נקבה    .    .    .    .    .    .  ...   ..   ..
# 14     אולפת   57  דרוזי  נקבה    .    .    .    .    .    .  ...    .    .
# 15    אומימה   54  דרוזי  נקבה    .    .    .    .    .    .  ...    .    .
# 16     אוסנת   79  דרוזי  נקבה    .    .    .    .    .    .  ...    .    .
# ..       ...  ...    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 402    תימאא  124  דרוזי  נקבה    .    .    .    .    .    .  ...   ..   ..
# 403     תלין   40  דרוזי  נקבה    .    .    .    .    .    .  ...   ..   ..
# 404     תמאר   54  דרוזי  נקבה    .    .    .    .    .    .  ...    .    .
# 405    תמימה  194  דרוזי  נקבה    5   ..   ..   ..    9   ..  ...   ..    .
# 406      תמר  150  דרוזי  נקבה    .    .    .    .    .    .  ...   ..   ..
#
# 11  2014 2015 2016 2017 2018 2019 2020 2021
# ...

# %%
#others Male
df_other_M=df_sheet_all['אחרים'][11:]
df_other_M.columns = df_other_M.iloc[0]
df_other_M=df_other_M[1:]
df_other_M.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_other_M.insert(2,'מגזר','אחר')
df_other_M.insert(3,'מין','זכר')
df_other_M
# Out:
# 11   שם פרטי סה"כ מגזר  מין 1949 1950 1951 1952 1953 1955  ... 2012 2013 2014  \
# 12     אביאל  223  אחר  זכר    .    .    .    .    .    .  ...    5   14   20
# 13      אביב  155  אחר  זכר    .    .    .    .    .    .  ...   10    7    5
# 14   אבראהים   44  אחר  זכר    .    .    .    .    .    .  ...    .    .    .
# 15     אברהם  106  אחר  זכר    .    .    .    .    .    .  ...   ..   ..    6
# 16    אדוארד  118  אחר  זכר    .    .    .    .    .    .  ...    6   ..    6
# ..       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 265     תומר  376  אחר  זכר    .    .    .    .    .    .  ...   21   13   11
# 266     תיאו   28  אחר  זכר    .    .    .    .    .    .  ...    .    .   ..
# 267  תיאודור   22  אחר  זכר    .    .    .    .    .    .  ...    .    .   ..
# 268    תימור   55  אחר  זכר    .    .    .    .    .    .  ...    6   ..   ..
# 269     תמיר  186  אחר  זכר    .    .    .    .    .    .  ...   13   10    7
#
# ...

# %%
#others feMale
df_other_F=df_sheet_all['אחרות'][11:]
df_other_F.columns = df_other_F.iloc[0]
df_other_F=df_other_F[1:]
df_other_F.rename(columns = {'סך הכל בשנים\n1948-2021':'סה"כ'}, inplace = True)
df_other_F.insert(2,'מגזר','אחר')
df_other_F.insert(3,'מין','נקבה')
df_other_F
# Out:
# 11  שם פרטי סה"כ מגזר   מין 1950 1951 1954 1955 1956 1965  ... 2012 2013 2014  \
# 12   אביגיל  196  אחר  נקבה    .    .    .    .    .    .  ...    8   14   12
# 13     אביה   35  אחר  נקבה    .    .    .    .    .    .  ...   ..   ..    .
# 14    אביטל  279  אחר  נקבה    .    .    .    .    .    .  ...    7   10    7
# 15    אבלין  119  אחר  נקבה    .    .    .    .    .    .  ...    7    9    7
# 16   אבלינה   64  אחר  נקבה    .    .    .    .    .    .  ...    5    5   ..
# ..      ...  ...  ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 284   תאלין   21  אחר  נקבה    .    .    .    .    .    .  ...   ..    .   ..
# 285     תהל   43  אחר  נקבה    .    .    .    .    .    .  ...   ..   ..    5
# 286   תולין   20  אחר  נקבה    .    .    .    .    .    .  ...    .    .   ..
# 287     תמר  117  אחר  נקבה    .    .    .    .    .    .  ...   ..   ..    7
# 288    תמרה   60  אחר  נקבה    .    .    .    .    .    .  ...   ..   ..   ..
#
# ...

# %%
vertical_concat = pd.concat([df_jews_M,df_jews_F,df_muslim_M,df_muslim_f,df_christan_M,df_christan_F,df_druze_M,df_druze_F,df_other_M,df_other_F], axis=0)
vertical_concat=vertical_concat.fillna(0)
vertical_concat = vertical_concat.replace(['..'], [0])
vertical_concat = vertical_concat.replace(['.'], [np.random.randint(0,5)])
vertical_concat
# Out:
# 11     שם פרטי  סה"כ   מגזר   מין  1948  1949  1950  1951  1952  1953  ...  \
# 12         אבא   179  יהודי   זכר     4     6     0     0     8     0  ...
# 13         אבי  9047  יהודי   זכר    34    49    53    79    92    80  ...
# 14   אבי-אברהם    29  יהודי   זכר     4     4     4     4     4     4  ...
# 15      אביאור   523  יהודי   זכר     4     4     4     4     4     4  ...
# 16       אביאל  5734  יהודי   זכר     0     0     0     0     0     0  ...
# ..         ...   ...    ...   ...   ...   ...   ...   ...   ...   ...  ...
# 284      תאלין    21    אחר  נקבה     0     0     4     4     0     0  ...
# 285        תהל    43    אחר  נקבה     0     0     4     4     0     0  ...
# 286      תולין    20    אחר  נקבה     0     0     4     4     0     0  ...
# 287        תמר   117    אחר  נקבה     0     0     4     4     0     0  ...
# 288       תמרה    60    אחר  נקבה     0     0     4     4     0     0  ...
#
# 11   2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
vertical_concat.columns.values
# Out:
# array(['שם פרטי', 'סה"כ', 'מגזר', 'מין', 1948, 1949, 1950, 1951, 1952,
#        1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963,
#        1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974,
#        1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021], dtype=object)

# %%
data_new = vertical_concat.reset_index(drop = True)    # Apply reset_index function
data_new
# Out:
# 11      שם פרטי  סה"כ   מגזר   מין  1948  1949  1950  1951  1952  1953  ...  \
# 0           אבא   179  יהודי   זכר     4     6     0     0     8     0  ...
# 1           אבי  9047  יהודי   זכר    34    49    53    79    92    80  ...
# 2     אבי-אברהם    29  יהודי   זכר     4     4     4     4     4     4  ...
# 3        אביאור   523  יהודי   זכר     4     4     4     4     4     4  ...
# 4         אביאל  5734  יהודי   זכר     0     0     0     0     0     0  ...
# ...         ...   ...    ...   ...   ...   ...   ...   ...   ...   ...  ...
# 6572      תאלין    21    אחר  נקבה     0     0     4     4     0     0  ...
# 6573        תהל    43    אחר  נקבה     0     0     4     4     0     0  ...
# 6574      תולין    20    אחר  נקבה     0     0     4     4     0     0  ...
# 6575        תמר   117    אחר  נקבה     0     0     4     4     0     0  ...
# 6576       תמרה    60    אחר  נקבה     0     0     4     4     0     0  ...
#
# ...

# %%
data_new.columns.values
#headers=list(df_jews_M.columns.values)
data_new.rename(columns = {'שם פרטי':'private name','סה"כ':'total','מגזר':'religion','מין':'sex',}, inplace = True)
data_new

data_new['religion'] = data_new['religion'].replace(['יהודי','מוסלמי','נוצרי','דרוזי','אחר'], ['jew','muslim','christan','druze','other'])
data_new['sex'] = data_new['sex'].replace('נקבה','Female')
data_new['sex'] = data_new['sex'].replace('זכר','Male')
data_new
# Out:
# 11   private name  total religion     sex  1948  1949  1950  1951  1952  1953  \
# 0             אבא    179      jew    Male     4     6     0     0     8     0
# 1             אבי   9047      jew    Male    34    49    53    79    92    80
# 2       אבי-אברהם     29      jew    Male     4     4     4     4     4     4
# 3          אביאור    523      jew    Male     4     4     4     4     4     4
# 4           אביאל   5734      jew    Male     0     0     0     0     0     0
# ...           ...    ...      ...     ...   ...   ...   ...   ...   ...   ...
# 6572        תאלין     21    other  Female     0     0     4     4     0     0
# 6573          תהל     43    other  Female     0     0     4     4     0     0
# 6574        תולין     20    other  Female     0     0     4     4     0     0
# 6575          תמר    117    other  Female     0     0     4     4     0     0
# 6576         תמרה     60    other  Female     0     0     4     4     0     0
#
# ...

# %%
gender=data_new.groupby(by=['sex'])['total'].sum()

# %%
gender
# Out:
# sex
# Female    3622360
# Male      3825806
# Name: total, dtype: int64

# %%
gender.plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
religion=data_new.groupby(by=['religion'])['total'].sum()
religion
# Out:
# religion
# christan     108595
# druze        103961
# jew         5598935
# muslim      1546102
# other         90573
# Name: total, dtype: int64

# %%
religion.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='religion'>

# %%
#data_new.set_index('index', inplace=True)
data_new = data_new.rename_axis(index=('index'), columns=None)
data_new
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 0              אבא    179      jew    Male     4     6     0     0     8
# 1              אבי   9047      jew    Male    34    49    53    79    92
# 2        אבי-אברהם     29      jew    Male     4     4     4     4     4
# 3           אביאור    523      jew    Male     4     4     4     4     4
# 4            אביאל   5734      jew    Male     0     0     0     0     0
# ...            ...    ...      ...     ...   ...   ...   ...   ...   ...
# 6572         תאלין     21    other  Female     0     0     4     4     0
# 6573           תהל     43    other  Female     0     0     4     4     0
# 6574         תולין     20    other  Female     0     0     4     4     0
# 6575           תמר    117    other  Female     0     0     4     4     0
# 6576          תמרה     60    other  Female     0     0     4     4     0
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
tamar=data_new.loc[data_new['private name'] == 'תמר']
tamar
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 1041           תמר    107      jew    Male     4     4     4     4     4
# 2516           תמר  39930      jew  Female    93   135   146   188   214
# 4736           תמר    185   muslim  Female     4     4     4     4     4
# 6041           תמר    150    druze  Female     4     4     4     4     4
# 6575           תמר    117    other  Female     0     0     4     4     0
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# index        ...
# 1041      4  ...     0     0     4     0     0     0     0     0     0     0
# 2516    211  ...  1322  1345  1461  1391  1349  1336  1340  1283  1174  1227
# 4736      4  ...     0     0     0     0     0     4     5     0     7     4
# 6041      4  ...     0     0     0     0     4     0     0     0     4     0
# 6575      0  ...     0     0     7     0     6     0     0     6     8     0
#
# [5 rows x 78 columns]

# %%
tamar.plot( 'religion' , 'total')
# Out:
# <AxesSubplot:xlabel='religion'>

# %%
chanan=data_new.loc[data_new['private name'] == 'חנן']
chanan
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 400            חנן   3036      jew    Male    22    39    42    52    45
# 3769           חנן    144   muslim  Female     4     4     4     4     4
# 5777           חנן     20    druze  Female     4     4     4     4     4
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# index        ...
# 400      50  ...     9     0     8     6     0     6     9     5     5     5
# 3769      4  ...     0     4     4     0     0     0     0     4     0     4
# 5777      4  ...     4     4     4     4     4     4     4     4     4     4
#
# [3 rows x 78 columns]

# %%
chanan.plot.bar(x='religion', y='total', rot=0)
# Out:
# <AxesSubplot:xlabel='religion'>

# %%
data_new[data_new['religion']=='jew'].sort_values(by = ['total', 'index'], ascending = [False, True])
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 315            דוד  66415      jew    Male   240   384   545   711   817
# 657            משה  62813      jew    Male   308   512   740   845   851
# 471           יוסף  61850      jew    Male   291   435   645   801   798
# 24           אברהם  55248      jew    Male   301   514   625   769   788
# 496           יעקב  48075      jew    Male   276   436   559   679   704
# ...            ...    ...      ...     ...   ...   ...   ...   ...   ...
# 966       שי-יהושע      9      jew    Male     4     4     4     4     4
# 1813           מון      9      jew  Female     4     4     4     4     4
# 492       יניב-משה      8      jew    Male     4     4     4     4     4
# 1303         ביריה      8      jew  Female     4     0     4     4     4
# 2148         עשורה      5      jew  Female     4     4     4     4     4
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
data_new.sort_values(by = ['total', 'index'], ascending = [False, True])
# Out:
#       private name   total religion     sex  1948  1949  1950  1951  1952  \
# index
# 2861         מוחמד  115356   muslim    Male   158   154   231   207   223
# 315            דוד   66415      jew    Male   240   384   545   711   817
# 657            משה   62813      jew    Male   308   512   740   845   851
# 471           יוסף   61850      jew    Male   291   435   645   801   798
# 24           אברהם   55248      jew    Male   301   514   625   769   788
# ...            ...     ...      ...     ...   ...   ...   ...   ...   ...
# 5744         האדיל       8    druze  Female     4     4     4     4     4
# 2653         גאית'       7   muslim    Male     4     4     4     4     4
# 4627          רמיה       7   muslim  Female     4     4     4     4     4
# 5963           פלק       7    druze  Female     4     4     4     4     4
# 2148         עשורה       5      jew  Female     4     4     4     4     4
#
# ...

# %%
data_new[data_new['private name']=='חנן'].sort_values(by = ['total', 'index'], ascending = [False, True])
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 400            חנן   3036      jew    Male    22    39    42    52    45
# 3769           חנן    144   muslim  Female     4     4     4     4     4
# 5777           חנן     20    druze  Female     4     4     4     4     4
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# index        ...
# 400      50  ...     9     0     8     6     0     6     9     5     5     5
# 3769      4  ...     0     4     4     0     0     0     0     4     0     4
# 5777      4  ...     4     4     4     4     4     4     4     4     4     4
#
# [3 rows x 78 columns]

# %%
data_new[data_new['private name']=='חנן'].sort_values(by = ['total', 'index'], ascending = [False, True])
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 400            חנן   3036      jew    Male    22    39    42    52    45
# 3769           חנן    144   muslim  Female     4     4     4     4     4
# 5777           חנן     20    druze  Female     4     4     4     4     4
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# index        ...
# 400      50  ...     9     0     8     6     0     6     9     5     5     5
# 3769      4  ...     0     4     4     0     0     0     0     4     0     4
# 5777      4  ...     4     4     4     4     4     4     4     4     4     4
#
# [3 rows x 78 columns]

# %%
data_new['private name'].describe()
# Out:
# count     6577
# unique    4241
# top        עדן
# freq         9
# Name: private name, dtype: object

# %%
data_new[data_new['private name']=='עדן'].describe()
# Out:
#               total      1948      1949  1950      1951      1952      1953  \
# count      9.000000  9.000000  9.000000   9.0  9.000000  9.000000  9.000000
# mean    2866.333333  3.111111  3.555556   4.0  3.111111  3.111111  3.111111
# std     5201.183303  1.763834  1.333333   0.0  1.763834  1.763834  1.763834
# min       76.000000  0.000000  0.000000   4.0  0.000000  0.000000  0.000000
# 25%      118.000000  4.000000  4.000000   4.0  4.000000  4.000000  4.000000
# 50%      340.000000  4.000000  4.000000   4.0  4.000000  4.000000  4.000000
# 75%     3852.000000  4.000000  4.000000   4.0  4.000000  4.000000  4.000000
# max    15931.000000  4.000000  4.000000   4.0  4.000000  4.000000  4.000000
#
#            1954      1955      1956  ...        2012        2013        2014  \
# count  9.000000  9.000000  9.000000  ...    9.000000    9.000000    9.000000
# mean   2.666667  2.666667  3.111111  ...   57.666667   51.888889   50.111111
# ...

# %%
data_new[data_new['private name']=='עדן'].sort_values(by = ['total', 'index'], ascending = [False, True])
# Out:
#       private name  total  religion     sex  1948  1949  1950  1951  1952  \
# index
# 2092           עדן  15931       jew  Female     4     4     4     0     0
# 4365           עדן   4597    muslim  Female     4     4     4     4     4
# 770            עדן   3852       jew    Male     4     4     4     4     4
# 6524           עדן    658     other  Female     0     0     4     4     0
# 5946           עדן    340     druze  Female     4     4     4     4     4
# 5571           עדן    130     druze    Male     4     4     4     4     4
# 6249           עדן    118     other    Male     0     4     4     4     4
# 5283           עדן     95  christan  Female     4     4     4     4     4
# 3042           עדן     76    muslim    Male     4     4     4     0     4
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# index        ...
# 2092      0  ...   294   285   266   256   239   254   181   205   177   165
# ...

# %%
#עדן מופיעה בכל מגזר!
#לעשות עדן לאורך זמן

# %%
#שמות חוצי מגזר: להציג בגרף
data_new['private name'].value_counts()
#data_new['private name'].sort_values(by = ['total', 'index'], ascending = [False, True])
# Out:
# עדן      9
# נור      9
# ליאם     7
# עדי      7
# מילאן    7
#         ..
# סימי     1
# סינדי    1
# סיניה    1
# סלביה    1
# ריאנה    1
# Name: private name, Length: 4241, dtype: int64

# %%
ser.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22748\3043126096.py in <module>
# ----> 1 ser.value_counts()
#
# NameError: name 'ser' is not defined

# %%
data_new
# Out:
#       private name  total religion     sex  1948  1949  1950  1951  1952  \
# index
# 0              אבא    179      jew    Male     4     6     0     0     8
# 1              אבי   9047      jew    Male    34    49    53    79    92
# 2        אבי-אברהם     29      jew    Male     4     4     4     4     4
# 3           אביאור    523      jew    Male     4     4     4     4     4
# 4            אביאל   5734      jew    Male     0     0     0     0     0
# ...            ...    ...      ...     ...   ...   ...   ...   ...   ...
# 6572         תאלין     21    other  Female     0     0     4     4     0
# 6573           תהל     43    other  Female     0     0     4     4     0
# 6574         תולין     20    other  Female     0     0     4     4     0
# 6575           תמר    117    other  Female     0     0     4     4     0
# 6576          תמרה     60    other  Female     0     0     4     4     0
#
#        1953  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
#tranpose
df_t = data_new.transpose()
df_t.columns = df_t.iloc[0]
df_t=df_t[4:]
df_t=df_t.rename_axis(index=('year'), columns=None)
df_t
# Out:
#      אבא אבי אבי-אברהם אביאור אביאל אביב אביגדור אבידור אבידן אבידע  ... שלי  \
# year                                                                 ...
# 1948   4  34         4      4     0    0      19      4     4     4  ...   0
# 1949   6  49         4      4     0    0      16      4     4     4  ...   0
# 1950   0  53         4      4     0    0      23      0     0     4  ...   4
# 1951   0  79         4      4     0    0      26      0     0     4  ...   4
# 1952   8  92         4      4     0    8      23      0     0     4  ...   0
# ...   ..  ..       ...    ...   ...  ...     ...    ...   ...   ...  ...  ..
# 2017   0  10         4     25   274  297      23      0     0     4  ...   9
# 2018   0   0         4     22   231  345      23      0     8     4  ...   8
# 2019   0   0         4     27   222  382      33      4     0     4  ...  12
# 2020   0  13         4     27   178  342      30      4     0     4  ...   0
# ...

# %%
df_t.index=pd.to_datetime(df_t.index, format='%Y')
df_t
# Out:
#            אבא אבי אבי-אברהם אביאור אביאל אביב אביגדור אבידור אבידן אבידע  \
# year
# 1948-01-01   4  34         4      4     0    0      19      4     4     4
# 1949-01-01   6  49         4      4     0    0      16      4     4     4
# 1950-01-01   0  53         4      4     0    0      23      0     0     4
# 1951-01-01   0  79         4      4     0    0      26      0     0     4
# 1952-01-01   8  92         4      4     0    8      23      0     0     4
# ...         ..  ..       ...    ...   ...  ...     ...    ...   ...   ...
# 2017-01-01   0  10         4     25   274  297      23      0     0     4
# 2018-01-01   0   0         4     22   231  345      23      0     8     4
# 2019-01-01   0   0         4     27   222  382      33      4     0     4
# 2020-01-01   0  13         4     27   178  342      30      4     0     4
# 2021-01-01   0  10         4     32   180  376      29      4     0     4
#
#             ... שלי שני שקד שרה שרון תאלין תהל תולין תמר תמרה
# ...

# %%
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(12, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Date")
plt.ylabel("Values")
plt.title("the name eden through years")
 
# plotting the "A" column alone
plt.plot(df_t["עדן"])

# %%
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(12, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Date")
plt.ylabel("Values")
plt.title("Sample Time Series Plot")
 
# plotting the "A" column alone
plt.plot(df_t["עדן"])

# %%
data3 = data_new.transpose()
data3=data3.drop('total')
data3.columns=pd.MultiIndex.from_arrays(data3.iloc[0:3].values)
data3=data3.iloc[3:]
data3['עדן']['jew']
data3.index=pd.to_datetime(data3.index, format='%Y')
data3
# Out:
#             אבא  אבי אבי-אברהם אביאור אביאל אביב אביגדור אבידור אבידן אבידע  \
#             jew  jew       jew    jew   jew  jew     jew    jew   jew   jew
#            Male Male      Male   Male  Male Male    Male   Male  Male  Male
# 1948-01-01    4   34         4      4     0    0      19      4     4     4
# 1949-01-01    6   49         4      4     0    0      16      4     4     4
# 1950-01-01    0   53         4      4     0    0      23      0     0     4
# 1951-01-01    0   79         4      4     0    0      26      0     0     4
# 1952-01-01    8   92         4      4     0    8      23      0     0     4
# ...         ...  ...       ...    ...   ...  ...     ...    ...   ...   ...
# 2017-01-01    0   10         4     25   274  297      23      0     0     4
# 2018-01-01    0    0         4     22   231  345      23      0     8     4
# 2019-01-01    0    0         4     27   222  382      33      4     0     4
# ...

# %%
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(12, 10))
 
plt.xlabel("Date")
plt.ylabel("Values")
plt.title("eden")
 
plt.plot(data3["עדן"]["jew"]["Female"])

# %%
#
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(12, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Date")
plt.ylabel("Values")
plt.title("Values of 'A' and Rolling Mean (2) Plot")
 
# plotting the "A" column and "A" column
# of Rolling Dataframe (window_size  = 20)
plt.plot(data3["עדן"])



plt.plot(data3.rolling(
  window=2, min_periods=1).mean()["עדן"])

# %%
data3['עדן'].describe()
# Out:
#         jew        muslim        christan druze        other
#        Male Female   Male Female   Female  Male Female  Male Female
# count    74     74     74     74       74    74     74    74     74
# unique   41     48      5     33        6     9     16     6     20
# top       0      0      4      4        4     4      4     4      4
# freq     17     15     45     26       48    45     42    37     30

# %%
data3['עדן']
# Out:
#             jew        muslim        christan druze        other
#            Male Female   Male Female   Female  Male Female  Male Female
# 1948-01-01    4      4      4      4        4     4      4     0      0
# 1949-01-01    4      4      4      4        4     4      4     4      0
# 1950-01-01    4      4      4      4        4     4      4     4      4
# 1951-01-01    4      0      0      4        4     4      4     4      4
# 1952-01-01    4      0      4      4        4     4      4     4      0
# ...         ...    ...    ...    ...      ...   ...    ...   ...    ...
# 2017-01-01   46    254      0     82        0     0      6     7     27
# 2018-01-01   39    181      4     77        0     0      6     0     20
# 2019-01-01   56    205      4     77        0     0      0     0     18
# 2020-01-01   56    177      0     81        0     0      0     5     21
# 2021-01-01   69    165      0     65        4     0      0     0     32
#
# [74 rows x 9 columns]

# %%
data3['עדן'].iloc[40:60]
# Out:
#             jew        muslim        christan druze        other
#            Male Female   Male Female   Female  Male Female  Male Female
# 1988-01-01   68     92      4      0        4     4      4     4      4
# 1989-01-01   79    168      0      5        4     4      0     4      0
# 1990-01-01  139    290      0      5        4     4      4     0      0
# 1991-01-01  164    330      0      8        4     0      4     4      4
# 1992-01-01  183    337      4     10        4     4      4     0      0
# 1993-01-01  243    477      0     14        4     4      4     0      0
# 1994-01-01  203    474      0     26        0     4      0     4      0
# 1995-01-01  268    691      0     37        4     0      4     0      0
# 1996-01-01  265   1203      0     43        0     0      0     0      0
# 1997-01-01  267   1265      7     67        0     0      7     6      9
# 1998-01-01  225   1054      0    133        7     0     16     7     16
# ...

# %%
(1203-691)/691
# Out:
# 0.7409551374819102
