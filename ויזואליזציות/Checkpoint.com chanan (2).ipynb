# %% [markdown]
# # use case by Chanan Jacobs

# %% [markdown]
# ### Call relevant libraries

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime 
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('whitegrid')
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.max_columns', None)
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ### format function so can see numbers in data frame in a neat way

# %%
def format_df_with_commas(df):
    def format_with_commas(x):
        return '{:,.0f}'.format(x)

    formatted_df = df.iloc[:, 1:].applymap(format_with_commas)
    result_df = pd.concat([df.iloc[:, 0], formatted_df], axis=1)
    return result_df

# %% [markdown]
# ### upload all data by sheet name

# %%
# List of sheet names
sheet_names = ['APAC Head Count', 'APAC Sales', 'APAC Expenses', 'APAC Total IT Spend']

#to store DataFrames
dfs = {}

#load data
for sheet_name in sheet_names:
    df = pd.read_excel('Check point data.xlsx', sheet_name=sheet_name)
    dfs[sheet_name] = df  # Store each DataFrame in the dictionary

for i, sheet_name in enumerate(sheet_names):
    globals()[f'df{i + 1}'] = dfs[sheet_name]

# %% [markdown]
# ### clean and re-organize head count data

# %%
df1a = df1.iloc[:15]
df1b =df1.iloc[16:]
df1b = df1b.dropna(how='all').reset_index(drop=True)
df1b.columns = df1b.iloc[0]
df1b = df1b.iloc[1:]
df1b.reset_index(drop=True, inplace=True)
Head_count = pd.merge(df1a,df1b,on =['Employee Country'],how ="right")

# %% [markdown]
# ### head count:

# %%
print(Head_count.shape)
Head_count
# Out:
# (15, 9)
#    Employee Country Q1-15 Q2-15 Q3-15 Q4-15 Q1-16 Q2-16 Q3-16 Q4-16
# 0         Australia    59    58    60    62    64    64    63    62
# 1             China    35    38    33    40    42    40    40    38
# 2         Hong Kong    18    17    19    18    20    19    18    19
# 3             India    32    38    41    47    48    47    44    49
# 4         Indonesia     6     6     6     6     6     6     5     6
# 5             Japan    26    32    33    34    41    44    41    42
# 6          Malaysia     3     3     3     3     3     3     3     3
# 7       New Zealand     6     6     6     6     9     9     9     9
# 8       Philippines     2     3     2     2     2     2     3     3
# 9         Singapore    30    31    34    38    42    48    55    54
# 10      South Korea     9    10    13    12    12    12     8     9
# 11           Taiwan    11    11    10    12    13    11    11    12
# 12         Thailand     3     4     3     4     4     4     4     5
# 13          Vietnam     2     3     3     3     3     3     3     3
# 14       APAC Total   242   260   266   287   309   312   307   314

# %% [markdown]
# ### clean and re-organize it spend data

# %%
df4a = df4.iloc[:13]
df4b =df4.iloc[15:]
df4b.columns = df4b.iloc[1]
df4b = df4b.iloc[2:]
it_spend = pd.merge(df4a,df4b,on =['Country'],how ="right")

# %% [markdown]
# ### it spend data:

# %%
print(it_spend.shape)
it_spend
# Out:
# (14, 7)
#         Country 2015 Populations (Millions) 2015 GDP ($ Billions)  \
# 0     Australia                          24                  1349
# 1         China                        1371                 11065
# 2     Hong Kong                           7                   309
# 3         India                        1309                  2102
# 4     Indonesia                         258                   861
# 5         Japan                         127                  4395
# 6      Malaysia                          31                   296
# 7   New Zealand                           5                   178
# 8   Philippines                         102                   293
# 9     Singapore                           6                   304
# 10  South Korea                          51                  1383
# 11       Taiwan                          23                   526
# 12     Thailand                          69                   401
# 13      Vietnam                         NaN                   NaN
#
#    2015 IT Spend ($ Millions) 2016 Populations (Millions)  \
# 0                       82651                          24
# 1                      211400                        1379
# 2                       18154                           7
# 3                       68850                        1324
# 4                        8571                         261
# 5                      609000                         127
# 6                       14872                          31
# 7                       10527                           5
# 8                        4063                         103
# 9                       25096                           6
# 10                        NaN                          51
# 11                      20411                          24
# 12                        NaN                          69
# 13                        NaN                          95
#
#    2016 GDP ($ Billions) 2016 IT Spend ($ Millions)
# 0                   1208                      84800
# 1                  11191                     226400
# 2                    321                      18572
# 3                   2274                      67740
# 4                    932                       9600
# 5                   4949                     627000
# 6                    297                      15794
# 7                    189                      10790
# 8                    305                       4400
# 9                    310                      26200
# 10                  1415                        NaN
# 11                   531                      20840
# 12                   412                        NaN
# 13                   205                        NaN

# %% [markdown]
# ### sales data:

# %%
sales=df2
print(sales.shape)
sales
# Out:
# (7524, 14)
#      Channel Country                         Sold to Name        Product Type  \
# 0          Australia  AFINA (CHILE) SISTEMAS INFORMATICOS          1. PRODUCT
# 1          Australia  AFINA (CHILE) SISTEMAS INFORMATICOS          3. SUPPORT
# 2          Australia  AFINA (CHILE) SISTEMAS INFORMATICOS  9.5 SERVICE BUNDLE
# 3          Australia  AFINA (CHILE) SISTEMAS INFORMATICOS   9.6 SERVICE BLADE
# 4          Australia  ALPHAWEST NSW TRADING AS OPTUS BUSI        5. MARKETING
# ...              ...                                  ...                 ...
# 7519         Vietnam      M-SECURITY TECHNOLOGY INDOCHINA   9.6 SERVICE BLADE
# 7520         Vietnam      M-SECURITY TECHNOLOGY INDOCHINA   9.6 SERVICE BLADE
# 7521         Vietnam      M-SECURITY TECHNOLOGY INDOCHINA   9.6 SERVICE BLADE
# 7522         Vietnam        M-SECURITY TECHNOLOGY SDN BHD          3. SUPPORT
# 7523         Vietnam        M-SECURITY TECHNOLOGY SDN BHD          3. SUPPORT
#
#               Product Sub-type        Product Family Material Classificat  \
# 0       1.25 Stand Alone (+HW)                  4400            APPLIANCE
# 1     3.92 Support EBS Premium  ENTERPRISE BASE SUPP             SOFTWARE
# 2        9.51 3 BLADES PACKAGE                  4400             SOFTWARE
# 3                9.25 ANTI BOT      SECURITY GATEWAY             SOFTWARE
# 4                  5.10 Events             MARKETING             SOFTWARE
# ...                        ...                   ...                  ...
# 7519     9.52 7 BLADES PACKAGE                 15600             SOFTWARE
# 7520     9.52 7 BLADES PACKAGE      SECURITY GATEWAY             SOFTWARE
# 7521                  9.65 IPS      SECURITY GATEWAY             SOFTWARE
# 7522           1.77 Sync. Fees            SYNC. FEES             SOFTWARE
# 7523            13 CES-PREMIUM                   CES             SOFTWARE
#
#       Q1-15 Booked Amount  Q2-15 Booked Amount  Q3-15 Booked Amount  \
# 0                    2482                  NaN                  NaN
# 1                    1095                  NaN                  NaN
# 2                     810                  NaN                  NaN
# 3                     975                  NaN                  NaN
# 4                     750                  NaN                  NaN
# ...                   ...                  ...                  ...
# 7519                  NaN                  NaN                  NaN
# 7520                  NaN                  NaN                  NaN
# 7521                    0                    0                 2187
# 7522                  NaN                  NaN                  NaN
# 7523                  NaN                  NaN                  NaN
#
#       Q4-15 Booked Amount  Q1-16 Booked Amount  Q2-16 Booked Amount  \
# 0                     NaN                  NaN                  NaN
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
# ...                   ...                  ...                  ...
# 7519                  NaN                  NaN                  NaN
# 7520                  NaN                  NaN                  NaN
# 7521                    0                    0                    0
# 7522                  NaN                  NaN                  460
# 7523                  NaN                  NaN                 3440
#
#       Q3-16 Booked Amount  Q4-16 Booked Amount
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# ...                   ...                  ...
# 7519                74100                  NaN
# 7520                 4116                  NaN
# 7521                    0                13133
# 7522                  NaN                  NaN
# 7523                  NaN                  NaN
#
# [7524 rows x 14 columns]

# %% [markdown]
# ### expenses data:

# %%
expenses=df3
print(expenses.shape)
expenses
# Out:
# (133, 29)
#        Country G/L Managerial group  Q1-15 Assigned  Q1-15 Plan  Q1-15 %  \
# 0    Australia         Compensation         2836736     3630228        1
# 1    Australia                Sales           40898        -411      100
# 2    Australia            Marketing          116542       81357        1
# 3    Australia           COOP & MDF           53963         NaN      NaN
# 4    Australia           Consulting             NaN         NaN      NaN
# ..         ...                  ...             ...         ...      ...
# 128     Taiwan               Result          310316      270504        1
# 129   Thailand           COOP & MDF           25608         NaN      NaN
# 130   Thailand               Result           25608         NaN      NaN
# 131    Vietnam           COOP & MDF           -1552         NaN      NaN
# 132    Vietnam               Result           -1552         NaN      NaN
#
#      Q2-15 Assigned  Q2-15 Plan  Q2-15 %  Q3-15 Assigned  Q3-15 Plan  Q3-15 %  \
# 0           3301299     4061025        1         3298871     5048734        1
# 1             60098        3300       18           80907       27166        3
# 2             95060      110000        1           69643       77614        1
# 3            108574         NaN      NaN           47774         NaN      NaN
# 4               NaN         NaN      NaN             NaN        3854      NaN
# ..              ...         ...      ...             ...         ...      ...
# 128          380818      362654        1          303474      333008        1
# 129           38789         NaN      NaN            4600         NaN      NaN
# 130           38789         NaN      NaN            4600         NaN      NaN
# 131           21483         NaN      NaN            1345         NaN      NaN
# 132           21483         NaN      NaN            1345         NaN      NaN
#
#      Q4-15 Assigned  Q4-15 Plan  Q4-15 %  Q1-16 Assigned  Q1-16 Plan  Q1-16 %  \
# 0           3430634     4830330        1         3385249     3835693        1
# 1             29745       51745        1           12294       41665        0
# 2            107481       59412        2          100192       96000        1
# 3            165196         NaN      NaN           56501         NaN      NaN
# 4               NaN         NaN      NaN             NaN         NaN      NaN
# ..              ...         ...      ...             ...         ...      ...
# 128          495890      312245        2          395052      341904        1
# 129           17400         NaN      NaN           28250         NaN      NaN
# 130           17400         NaN      NaN           28250         NaN      NaN
# 131           29154         NaN      NaN            8080         NaN      NaN
# 132           29154         NaN      NaN            8080         NaN      NaN
#
#      Q2-16 Assigned  Q2-16 Plan  Q2-16 %  Q3-16 Assigned  Q3-16 Plan  Q3-16 %  \
# 0           3675202     4081638        1         3630831     4147712        1
# 1             58114       63577        1           35870       85033        0
# 2             58375      156000        0          131083      166000        1
# 3             72504         NaN      NaN           71940         NaN      NaN
# 4               NaN         NaN      NaN             NaN         NaN      NaN
# ..              ...         ...      ...             ...         ...      ...
# 128          339115      384156        1          268597      415702        1
# 129            9106         NaN      NaN           51351         NaN      NaN
# 130            9106         NaN      NaN           51351         NaN      NaN
# 131           29204         NaN      NaN            5880         NaN      NaN
# 132           29204         NaN      NaN            5880         NaN      NaN
#
#      Q4-16 Assigned  Q4-16 Plan  Q4-16 %  Overall Result Assigned  \
# 0           3515393     4173680        1                 27074216
# 1             54040       31232        2                   371967
# 2             95414      146000        1                   773790
# 3             63048         NaN      NaN                   639499
# 4               NaN         NaN      NaN                      NaN
# ..              ...         ...      ...                      ...
# 128          448539      601983        1                  2941802
# 129          -28554         NaN      NaN                   146550
# 130          -28554         NaN      NaN                   146550
# 131           21670         NaN      NaN                   115264
# 132           21670         NaN      NaN                   115264
#
#      Overall Result Plan  Overall Result %
# 0               33809040                 1
# 1                 303307                 1
# 2                 892383                 1
# 3                    NaN               NaN
# 4                   3854               NaN
# ..                   ...               ...
# 128              3022156                 1
# 129                  NaN               NaN
# 130                  NaN               NaN
# 131                  NaN               NaN
# 132                  NaN               NaN
#
# [133 rows x 29 columns]

# %% [markdown]
# ### the quartes array

# %%
quarters = ['Q1-15', 'Q2-15', 'Q3-15', 'Q4-15', 'Q1-16', 'Q2-16', 'Q3-16', 'Q4-16']

# %% [markdown]
# ### create array of all columns to group by

# %%
columns_to_sum=[]
for quarter in quarters:
    Booked_col = f'{quarter} Booked Amount'
    columns_to_sum.append(Booked_col)

# %% [markdown]
# ### sum all booked amount to quarter by country (income)

# %%
country_sum= sales.groupby('Channel Country')[columns_to_sum].sum().reset_index()
country_sum
# Out:
#    Channel Country  Q1-15 Booked Amount  Q2-15 Booked Amount  \
# 0        Australia              9126852             15628393
# 1            China              2754516              2788034
# 2        Hong Kong              2841954              2037812
# 3            India              7374906              7512036
# 4        Indonesia              1531164              2082379
# 5            Japan              5442290              6286630
# 6         Malaysia               690406               613399
# 7      New Zealand              1040969              2811715
# 8      Philippines               718037              1279732
# 9        Singapore              4629364              4435645
# 10     South Korea               846581              1738190
# 11          Taiwan              1398195              1184560
# 12        Thailand              1137785               802677
# 13         Vietnam               551239               957765
#
#     Q3-15 Booked Amount  Q4-15 Booked Amount  Q1-16 Booked Amount  \
# 0              15505620             10490510              8297715
# 1               3642114              3310420              3258575
# 2               2837282              4117942              3009109
# 3               7179319              6634408              7923857
# 4               1690983              1892150              1601804
# 5               5515913              5376888              7438962
# 6               1180275               833491              1432689
# 7               3654762              2696677              1685724
# 8                755938              1110287              1370911
# 9               5731311              7524770              6453115
# 10              1244469              1611888               861286
# 11              1166380              1152229              1021420
# 12               816400              1415766               914105
# 13               726852               961504               636445
#
#     Q2-16 Booked Amount  Q3-16 Booked Amount  Q4-16 Booked Amount
# 0              19008654             13630455             13840018
# 1               3146073              3757800              4161587
# 2               6258058              3222807              4099353
# 3               7945253              8009614             10873627
# 4               1649842              1653837              1986890
# 5               8775265              9120352              8344142
# 6                532326               754845              1280254
# 7               3468957              2715159              3023868
# 8               1440882              1543800              1194325
# 9               5821284              8085223              9485651
# 10              1096763              1780720              1310771
# 11              1211920              1417067              1595693
# 12               881592              1609666              2451321
# 13               842861              1120837              1456151

# %% [markdown]
# #### first i would like to seein a general way how much money each country spends

# %% [markdown]
# ### plot all countries income

# %%
# Define a function to format y-axis labels with dollar signs
def dollar_formatter(x, pos):
    return f"${x/1e6:.1f}M"  # Convert the value to millions and format as $X.XM
formatter = FuncFormatter(dollar_formatter)

#define which data to plot:
df = pd.DataFrame(country_sum)
df.set_index('Channel Country', inplace=True)

#style:
colors = plt.cm.get_cmap('tab20', len(df.index))
legend_markers = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors(np.arange(len(df.index)))]
plt.figure(figsize=(14, 8))

# Plot the data for each country 
for i, country in enumerate(df.index):
    plt.plot(df.columns, df.loc[country], label=country, linestyle='-', color=colors(i))
    
# ticks values:
plt.xticks(range(len(quarters)), quarters, rotation=0, fontsize=15, fontweight='bold')
plt.yticks(fontsize=15,fontweight ='bold')
plt.gca().yaxis.set_major_formatter(formatter)

plt.title('Booked amount by country in millions $ ', fontsize=20,fontweight ='bold')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=15)


plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ####

# %% [markdown]
# #### search for ptterns over time, it seems in general that there is a Steady increase in numbers

# %% [markdown]
# ### countries income disturbution

# %%
# Create a strip plot (swarm plot) to show each data point individually
plt.figure(figsize=(10, 5))
sns.stripplot(data=country_sum.drop('Channel Country', axis=1), color='blue', jitter=0.2, alpha=0.5)

head = 'Booked amount disturbution'

plt.title(head, fontweight='bold')
plt.xticks(range(len(quarters)), quarters,rotation=0, fontsize=10, fontweight='bold')
plt.yticks(fontsize=10,fontweight ='bold')

plt.gca().yaxis.set_major_formatter(formatter)
plt.show()

# %% [markdown]
# ####

# %% [markdown]
# #### i would like to re- organize data in a way that i can consider what country i should look more deeply in to

# %% [markdown]
# ### calcualte country average and quarter average

# %%
country_sum['average']=country_sum.mean(axis=1)

column_averages = pd.DataFrame(country_sum.mean(axis=0))
column_averages=column_averages.transpose()

result = pd.concat([country_sum, column_averages], ignore_index=True)
column_averages = column_averages.rename(index={0: 'average'})

result.at[14, 'Channel Country'] = 'average'
result = result.sort_values(by='Channel Country', ascending=True)
result=result.reset_index(drop = True)    
result
# Out:
#    Channel Country  Q1-15 Booked Amount  Q2-15 Booked Amount  \
# 0        Australia              9126852             15628393
# 1            China              2754516              2788034
# 2        Hong Kong              2841954              2037812
# 3            India              7374906              7512036
# 4        Indonesia              1531164              2082379
# 5            Japan              5442290              6286630
# 6         Malaysia               690406               613399
# 7      New Zealand              1040969              2811715
# 8      Philippines               718037              1279732
# 9        Singapore              4629364              4435645
# 10     South Korea               846581              1738190
# 11          Taiwan              1398195              1184560
# 12        Thailand              1137785               802677
# 13         Vietnam               551239               957765
# 14         average              2863161              3582783
#
#     Q3-15 Booked Amount  Q4-15 Booked Amount  Q1-16 Booked Amount  \
# 0              15505620             10490510              8297715
# 1               3642114              3310420              3258575
# 2               2837282              4117942              3009109
# 3               7179319              6634408              7923857
# 4               1690983              1892150              1601804
# 5               5515913              5376888              7438962
# 6               1180275               833491              1432689
# 7               3654762              2696677              1685724
# 8                755938              1110287              1370911
# 9               5731311              7524770              6453115
# 10              1244469              1611888               861286
# 11              1166380              1152229              1021420
# 12               816400              1415766               914105
# 13               726852               961504               636445
# 14              3689116              3509209              3278980
#
#     Q2-16 Booked Amount  Q3-16 Booked Amount  Q4-16 Booked Amount  average
# 0              19008654             13630455             13840018 13191027
# 1               3146073              3757800              4161587  3352390
# 2               6258058              3222807              4099353  3553040
# 3               7945253              8009614             10873627  7931628
# 4               1649842              1653837              1986890  1761131
# 5               8775265              9120352              8344142  7037555
# 6                532326               754845              1280254   914711
# 7               3468957              2715159              3023868  2637229
# 8               1440882              1543800              1194325  1176739
# 9               5821284              8085223              9485651  6520795
# 10              1096763              1780720              1310771  1311334
# 11              1211920              1417067              1595693  1268433
# 12               881592              1609666              2451321  1253664
# 13               842861              1120837              1456151   906707
# 14              4434266              4173013              4650261  3772599

# %% [markdown]
# ####

# %% [markdown]
# #### its easy to see that Australia is the main country that provides Checkpoint its income, after it is japan india and singapore

# %% [markdown]
# ### plot average income by country

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Channel Country', y='average', data=country_sum.sort_values(by='average', ascending=False),color='blue',alpha=0.9,linewidth=2, edgecolor='black')
plt.xticks(rotation=90)
plt.title('Average Booked Amount by Country')
plt.gca().yaxis.set_major_formatter(formatter)
plt.ylabel('Average Booked Amount',fontweight ='bold')
plt.show()

# %% [markdown]
# #### steady increase in income

# %% [markdown]
# ### plot average income by quarter

# %%
quarterly_averages = result.iloc[14, 1:-1] 

plt.figure(figsize=(10, 6))
sns.barplot(x=quarters, y=quarterly_averages,color='blue',alpha=1,linewidth=2, edgecolor='black')



plt.xticks(rotation=0)
plt.xlabel('Quarter')
plt.ylabel('Average Booked Amount')
plt.title('Average Booked Amount by Quarter')
plt.gca().yaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# ### plot average income by country pie

# %%
countries = country_sum['Channel Country']
averages = country_sum['average']

# Create a pie plot
plt.figure(figsize=(10, 8))
plt.pie(averages, labels=countries, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Average Booked Amount: ', loc='left', pad=20)
plt.show()

# %% [markdown]
# ### top 3 and bottom 3 countries

# %%
toplot=result.sort_values(by='average', ascending=False).drop('average',axis=1)
top3 = toplot.head(3).reset_index(drop=True)
top3.columns = [col.replace('Booked Amount', '') if col != 'Channel Country' else col for col in top3.columns]
toplot=result.drop('average',axis=1)
bottom3 = toplot.tail(4)
bottom3.columns = [col.replace('Booked Amount', '') if col != 'Channel Country' else col for col in bottom3.columns]

# %%
top3
# Out:
#   Channel Country  Q1-15    Q2-15    Q3-15    Q4-15   Q1-16    Q2-16   \
# 0       Australia 9126852 15628393 15505620 10490510 8297715 19008654
# 1           India 7374906  7512036  7179319  6634408 7923857  7945253
# 2           Japan 5442290  6286630  5515913  5376888 7438962  8775265
#
#     Q3-16    Q4-16
# 0 13630455 13840018
# 1  8009614 10873627
# 2  9120352  8344142

# %%
bottom3
# Out:
#    Channel Country  Q1-15   Q2-15   Q3-15   Q4-15   Q1-16   Q2-16   Q3-16   \
# 11          Taiwan 1398195 1184560 1166380 1152229 1021420 1211920 1417067
# 12        Thailand 1137785  802677  816400 1415766  914105  881592 1609666
# 13         Vietnam  551239  957765  726852  961504  636445  842861 1120837
# 14         average 2863161 3582783 3689116 3509209 3278980 4434266 4173013
#
#     Q4-16
# 11 1595693
# 12 2451321
# 13 1456151
# 14 4650261

# %% [markdown]
# ### organize Assigned vs planned data:

# %%
Assigned_vs_planned=expenses.loc[(expenses['G/L Managerial group']=='Result')]
#reorganize table:
selected_columns = expenses.columns[2:-2]
columns_to_sum = expenses.loc[:, selected_columns]
non_percentage_columns = [col for col in columns_to_sum.columns if not col.endswith('%')]
#sum all columns:

Assigned_vs_planned = Assigned_vs_planned.groupby('Country')[non_percentage_columns].sum().reset_index()
Assigned_vs_planned= Assigned_vs_planned.drop('Overall Result Assigned',axis=1)
Assigned_vs_planned
# Out:
#         Country  Q1-15 Assigned  Q1-15 Plan  Q2-15 Assigned  Q2-15 Plan  \
# 0     Australia         3792122     4304593         4027271     5040144
# 1         China         1524745      794669         1369520     1624444
# 2     Hong Kong          654200     1067402         1111935     1299728
# 3         India          763303      758538         1134185      923719
# 4     Indonesia           18711           0          154260           0
# 5         Japan         1629287     2189830         1581289     1921157
# 6         Korea          279313      377026          393621      408330
# 7      Malaysia           17535           0           12666           0
# 8   New Zealand           23030           0           13950           0
# 9   Philippines           16239           0           -2625           0
# 10    Singapore         1792209     1399481         2204338     1781059
# 11       Taiwan          310316      270504          380818      362654
# 12     Thailand           25608           0           38789           0
# 13      Vietnam           -1552           0           21483           0
#
#     Q3-15 Assigned  Q3-15 Plan  Q4-15 Assigned  Q4-15 Plan  Q1-16 Assigned  \
# 0          4107898     6091680         4374478     5811348         4099873
# 1          1688443     1770751         -117286     1453776         1401391
# 2           882590     2084343         1758212     1522002          712059
# 3          1170611     1009324         1594401     1070524         1624613
# 4            57659           0           80553           0          105724
# 5          1518888     2150425         1702619     2016750         2272267
# 6           419013      434397          455730      504087          463677
# 7             3600           0           11336           0            9620
# 8            16800           0           37950           0          264720
# 9            22555           0           22652           0            1625
# 10         1846802     2056932         2030955     1643724         2231857
# 11          303474      333008          495890      312245          395052
# 12            4600           0           17400           0           28250
# 13            1345           0           29154           0            8080
#
#     Q1-16 Plan  Q2-16 Assigned  Q2-16 Plan  Q3-16 Assigned  Q3-16 Plan  \
# 0      4760905         4512433     4909932         4582823     5077196
# 1      2187838         1721697     1618537         1778212     1691946
# 2       868309          773469      934149          986533      976596
# 3       974995         1485179     1340523         1273656     1405112
# 4        79732           95212      170488          174098      250931
# 5      2030296         2931198     1970709         2771516     2242466
# 6       412862          422661      468600          249565      487150
# 7            0            7511           0           25050           0
# 8            0          440720           0          567052           0
# 9            0           14181           0           49837           0
# 10     1634087         2598767     1930305         3263714     2120802
# 11      341904          339115      384156          268597      415702
# 12           0            9106           0           51351           0
# 13           0           29204           0            5880           0
#
#     Q4-16 Assigned  Q4-16 Plan
# 0          4216325     4972382
# 1          1482648       42924
# 2          1068818     1005085
# 3          1223163     1349923
# 4            78866      330580
# 5          2404168     2006255
# 6           398161      511047
# 7            -6814           0
# 8           515731           0
# 9            -1152           0
# 10         3260291     2063248
# 11          448539      601983
# 12          -28554           0
# 13           21670           0

# %% [markdown]
# ### assigned vs planned data:

# %%
# Calculate the percentage for each quarter and add new columns
for quarter in quarters:
    assigned_col = f'{quarter} Assigned'
    plan_col = f'{quarter} Plan'
    percentage_col = f'{quarter} %'
    Assigned_vs_planned[percentage_col] = (Assigned_vs_planned[assigned_col] / Assigned_vs_planned[plan_col]) * 100

# %%
Assigned_vs_planned
# Out:
#         Country  Q1-15 Assigned  Q1-15 Plan  Q2-15 Assigned  Q2-15 Plan  \
# 0     Australia         3792122     4304593         4027271     5040144
# 1         China         1524745      794669         1369520     1624444
# 2     Hong Kong          654200     1067402         1111935     1299728
# 3         India          763303      758538         1134185      923719
# 4     Indonesia           18711           0          154260           0
# 5         Japan         1629287     2189830         1581289     1921157
# 6         Korea          279313      377026          393621      408330
# 7      Malaysia           17535           0           12666           0
# 8   New Zealand           23030           0           13950           0
# 9   Philippines           16239           0           -2625           0
# 10    Singapore         1792209     1399481         2204338     1781059
# 11       Taiwan          310316      270504          380818      362654
# 12     Thailand           25608           0           38789           0
# 13      Vietnam           -1552           0           21483           0
#
#     Q3-15 Assigned  Q3-15 Plan  Q4-15 Assigned  Q4-15 Plan  Q1-16 Assigned  \
# 0          4107898     6091680         4374478     5811348         4099873
# 1          1688443     1770751         -117286     1453776         1401391
# 2           882590     2084343         1758212     1522002          712059
# 3          1170611     1009324         1594401     1070524         1624613
# 4            57659           0           80553           0          105724
# 5          1518888     2150425         1702619     2016750         2272267
# 6           419013      434397          455730      504087          463677
# 7             3600           0           11336           0            9620
# 8            16800           0           37950           0          264720
# 9            22555           0           22652           0            1625
# 10         1846802     2056932         2030955     1643724         2231857
# 11          303474      333008          495890      312245          395052
# 12            4600           0           17400           0           28250
# 13            1345           0           29154           0            8080
#
#     Q1-16 Plan  Q2-16 Assigned  Q2-16 Plan  Q3-16 Assigned  Q3-16 Plan  \
# 0      4760905         4512433     4909932         4582823     5077196
# 1      2187838         1721697     1618537         1778212     1691946
# 2       868309          773469      934149          986533      976596
# 3       974995         1485179     1340523         1273656     1405112
# 4        79732           95212      170488          174098      250931
# 5      2030296         2931198     1970709         2771516     2242466
# 6       412862          422661      468600          249565      487150
# 7            0            7511           0           25050           0
# 8            0          440720           0          567052           0
# 9            0           14181           0           49837           0
# 10     1634087         2598767     1930305         3263714     2120802
# 11      341904          339115      384156          268597      415702
# 12           0            9106           0           51351           0
# 13           0           29204           0            5880           0
#
#     Q4-16 Assigned  Q4-16 Plan  Q1-15 %  Q2-15 %  Q3-15 %  Q4-15 %  Q1-16 %  \
# 0          4216325     4972382       88       80       67       75       86
# 1          1482648       42924      192       84       95       -8       64
# 2          1068818     1005085       61       86       42      116       82
# 3          1223163     1349923      101      123      116      149      167
# 4            78866      330580      inf      inf      inf      inf      133
# 5          2404168     2006255       74       82       71       84      112
# 6           398161      511047       74       96       96       90      112
# 7            -6814           0      inf      inf      inf      inf      inf
# 8           515731           0      inf      inf      inf      inf      inf
# 9            -1152           0      inf     -inf      inf      inf      inf
# 10         3260291     2063248      128      124       90      124      137
# 11          448539      601983      115      105       91      159      116
# 12          -28554           0      inf      inf      inf      inf      inf
# 13           21670           0     -inf      inf      inf      inf      inf
#
#     Q2-16 %  Q3-16 %  Q4-16 %
# 0        92       90       85
# 1       106      105     3454
# 2        83      101      106
# 3       111       91       91
# 4        56       69       24
# 5       149      124      120
# 6        90       51       78
# 7       inf      inf     -inf
# 8       inf      inf      inf
# 9       inf      inf     -inf
# 10      135      154      158
# 11       88       65       75
# 12      inf      inf     -inf
# 13      inf      inf      inf

# %% [markdown]
# ### some countries didnt planned a budget at all

# %%
selected_columns = [Assigned_vs_planned.columns[0]] + Assigned_vs_planned.columns[-8:].tolist()
Assigned_vs_planned[selected_columns]
# Out:
#         Country  Q1-15 %  Q2-15 %  Q3-15 %  Q4-15 %  Q1-16 %  Q2-16 %  \
# 0     Australia       88       80       67       75       86       92
# 1         China      192       84       95       -8       64      106
# 2     Hong Kong       61       86       42      116       82       83
# 3         India      101      123      116      149      167      111
# 4     Indonesia      inf      inf      inf      inf      133       56
# 5         Japan       74       82       71       84      112      149
# 6         Korea       74       96       96       90      112       90
# 7      Malaysia      inf      inf      inf      inf      inf      inf
# 8   New Zealand      inf      inf      inf      inf      inf      inf
# 9   Philippines      inf     -inf      inf      inf      inf      inf
# 10    Singapore      128      124       90      124      137      135
# 11       Taiwan      115      105       91      159      116       88
# 12     Thailand      inf      inf      inf      inf      inf      inf
# 13      Vietnam     -inf      inf      inf      inf      inf      inf
#
#     Q3-16 %  Q4-16 %
# 0        90       85
# 1       105     3454
# 2       101      106
# 3        91       91
# 4        69       24
# 5       124      120
# 6        51       78
# 7       inf     -inf
# 8       inf      inf
# 9       inf     -inf
# 10      154      158
# 11       65       75
# 12      inf     -inf
# 13      inf      inf

# %% [markdown]
# ### leave just assigned data:

# %%
assigned_columns = [col for col in Assigned_vs_planned.columns if col.endswith("Assigned")]

# Include the "Country" column in the list
selected_columns = ['Country'] + assigned_columns

assigned_data = Assigned_vs_planned[selected_columns]
assigned_data
# Out:
#         Country  Q1-15 Assigned  Q2-15 Assigned  Q3-15 Assigned  \
# 0     Australia         3792122         4027271         4107898
# 1         China         1524745         1369520         1688443
# 2     Hong Kong          654200         1111935          882590
# 3         India          763303         1134185         1170611
# 4     Indonesia           18711          154260           57659
# 5         Japan         1629287         1581289         1518888
# 6         Korea          279313          393621          419013
# 7      Malaysia           17535           12666            3600
# 8   New Zealand           23030           13950           16800
# 9   Philippines           16239           -2625           22555
# 10    Singapore         1792209         2204338         1846802
# 11       Taiwan          310316          380818          303474
# 12     Thailand           25608           38789            4600
# 13      Vietnam           -1552           21483            1345
#
#     Q4-15 Assigned  Q1-16 Assigned  Q2-16 Assigned  Q3-16 Assigned  \
# 0          4374478         4099873         4512433         4582823
# 1          -117286         1401391         1721697         1778212
# 2          1758212          712059          773469          986533
# 3          1594401         1624613         1485179         1273656
# 4            80553          105724           95212          174098
# 5          1702619         2272267         2931198         2771516
# 6           455730          463677          422661          249565
# 7            11336            9620            7511           25050
# 8            37950          264720          440720          567052
# 9            22652            1625           14181           49837
# 10         2030955         2231857         2598767         3263714
# 11          495890          395052          339115          268597
# 12           17400           28250            9106           51351
# 13           29154            8080           29204            5880
#
#     Q4-16 Assigned
# 0          4216325
# 1          1482648
# 2          1068818
# 3          1223163
# 4            78866
# 5          2404168
# 6           398161
# 7            -6814
# 8           515731
# 9            -1152
# 10         3260291
# 11          448539
# 12          -28554
# 13           21670

# %% [markdown]
# ###

# %% [markdown]
# ### leave just booked data:

# %%
booked_data = result.rename(columns={result.columns[0]: "Country"})
booked_data=booked_data.sort_values(by='Country', ascending=True).reset_index(drop=True)
booked_data
# Out:
#         Country  Q1-15 Booked Amount  Q2-15 Booked Amount  \
# 0     Australia              9126852             15628393
# 1         China              2754516              2788034
# 2     Hong Kong              2841954              2037812
# 3         India              7374906              7512036
# 4     Indonesia              1531164              2082379
# 5         Japan              5442290              6286630
# 6      Malaysia               690406               613399
# 7   New Zealand              1040969              2811715
# 8   Philippines               718037              1279732
# 9     Singapore              4629364              4435645
# 10  South Korea               846581              1738190
# 11       Taiwan              1398195              1184560
# 12     Thailand              1137785               802677
# 13      Vietnam               551239               957765
# 14      average              2863161              3582783
#
#     Q3-15 Booked Amount  Q4-15 Booked Amount  Q1-16 Booked Amount  \
# 0              15505620             10490510              8297715
# 1               3642114              3310420              3258575
# 2               2837282              4117942              3009109
# 3               7179319              6634408              7923857
# 4               1690983              1892150              1601804
# 5               5515913              5376888              7438962
# 6               1180275               833491              1432689
# 7               3654762              2696677              1685724
# 8                755938              1110287              1370911
# 9               5731311              7524770              6453115
# 10              1244469              1611888               861286
# 11              1166380              1152229              1021420
# 12               816400              1415766               914105
# 13               726852               961504               636445
# 14              3689116              3509209              3278980
#
#     Q2-16 Booked Amount  Q3-16 Booked Amount  Q4-16 Booked Amount  average
# 0              19008654             13630455             13840018 13191027
# 1               3146073              3757800              4161587  3352390
# 2               6258058              3222807              4099353  3553040
# 3               7945253              8009614             10873627  7931628
# 4               1649842              1653837              1986890  1761131
# 5               8775265              9120352              8344142  7037555
# 6                532326               754845              1280254   914711
# 7               3468957              2715159              3023868  2637229
# 8               1440882              1543800              1194325  1176739
# 9               5821284              8085223              9485651  6520795
# 10              1096763              1780720              1310771  1311334
# 11              1211920              1417067              1595693  1268433
# 12               881592              1609666              2451321  1253664
# 13               842861              1120837              1456151   906707
# 14              4434266              4173013              4650261  3772599

# %%
result=result.reset_index(drop=True)
result.rename(columns={'Channel Country': 'Country'}, inplace=True)

# %% [markdown]
# ###

# %% [markdown]
# ### ROI

# %%
merge_roi = result.merge(assigned_data, on='Country')
#(south korea and average dropped)

for quarter in quarters:
    Booked_col = f'{quarter} Booked Amount'
    Assigned_col = f'{quarter} Assigned'
    percentage_col = f'{quarter} %'
    merge_roi[percentage_col] = (merge_roi[Booked_col] / merge_roi[Assigned_col]) *100
    
selected_columns = [merge_roi.columns[0]] + merge_roi.columns[-8:].tolist()
merge_roi[selected_columns]
# Out:
#         Country  Q1-15 %  Q2-15 %  Q3-15 %  Q4-15 %  Q1-16 %  Q2-16 %  \
# 0     Australia      241      388      377      240      202      421
# 1         China      181      204      216    -2823      233      183
# 2     Hong Kong      434      183      321      234      423      809
# 3         India      966      662      613      416      488      535
# 4     Indonesia     8183     1350     2933     2349     1515     1733
# 5         Japan      334      398      363      316      327      299
# 6      Malaysia     3937     4843    32785     7353    14893     7087
# 7   New Zealand     4520    20156    21755     7106      637      787
# 8   Philippines     4422   -48752     3352     4901    84364    10161
# 9     Singapore      258      201      310      371      289      224
# 10       Taiwan      451      311      384      232      259      357
# 11     Thailand     4443     2069    17748     8137     3236     9681
# 12      Vietnam   -35518     4458    54041     3298     7877     2886
#
#     Q3-16 %  Q4-16 %
# 0       297      328
# 1       211      281
# 2       327      384
# 3       629      889
# 4       950     2519
# 5       329      347
# 6      3013   -18789
# 7       479      586
# 8      3098  -103674
# 9       248      291
# 10      528      356
# 11     3135    -8585
# 12    19062     6720

# %%
merge_plot=merge_roi[selected_columns]
merge_roi[selected_columns]
# Out:
#         Country  Q1-15 %  Q2-15 %  Q3-15 %  Q4-15 %  Q1-16 %  Q2-16 %  \
# 0     Australia      241      388      377      240      202      421
# 1         China      181      204      216    -2823      233      183
# 2     Hong Kong      434      183      321      234      423      809
# 3         India      966      662      613      416      488      535
# 4     Indonesia     8183     1350     2933     2349     1515     1733
# 5         Japan      334      398      363      316      327      299
# 6      Malaysia     3937     4843    32785     7353    14893     7087
# 7   New Zealand     4520    20156    21755     7106      637      787
# 8   Philippines     4422   -48752     3352     4901    84364    10161
# 9     Singapore      258      201      310      371      289      224
# 10       Taiwan      451      311      384      232      259      357
# 11     Thailand     4443     2069    17748     8137     3236     9681
# 12      Vietnam   -35518     4458    54041     3298     7877     2886
#
#     Q3-16 %  Q4-16 %
# 0       297      328
# 1       211      281
# 2       327      384
# 3       629      889
# 4       950     2519
# 5       329      347
# 6      3013   -18789
# 7       479      586
# 8      3098  -103674
# 9       248      291
# 10      528      356
# 11     3135    -8585
# 12    19062     6720

# %%
filtered_data = merge_plot.drop('Country', axis=1)
filtered_data = filtered_data[(filtered_data >= -400) & (filtered_data <= 400)]

# Define the quarters for x-axis labels
quarters = ['Q1-15', 'Q2-15', 'Q3-15', 'Q4-15', 'Q1-16', 'Q2-16', 'Q3-16', 'Q4-16']

# Calculate the mean for each quarter
means = filtered_data.mean()

# Create a strip plot
plt.figure(figsize=(10, 5))
sns.stripplot(data=filtered_data, color='blue', jitter=0.2, alpha=0.5)

# Plotting the average line for each quarter
for i, mean in enumerate(means):
    plt.axhline(y=mean, color='red', linestyle='-', linewidth=1, xmin=i/len(means)-1/(2*len(means)), xmax=(i+1)/len(means)-1/(2*len(means)))

# Set title and labels
head = 'ROI Distribution with Quarterly Averages'
plt.title(head, fontweight='bold')
plt.xticks(range(len(quarters)), quarters, rotation=0, fontsize=10, fontweight='bold')
plt.yticks(fontsize=10, fontweight='bold')

# Show the plot
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ### average it spend for person:

# %%
df = pd.DataFrame(it_spend)
# Calculate average IT spending per capita for 2015 and 2016
df['2015 IT Spend per Capita'] = df['2015 IT Spend ($ Millions)'] / (df['2015 Populations (Millions)'] * 1)
df['2016 IT Spend per Capita'] = df['2016 IT Spend ($ Millions)'] / (df['2016 Populations (Millions)'] * 1)

# Create an array for x-axis positions
x = np.arange(len(df['Country']))

# Set the width of the bars
bar_width = 0.35

# Create a grouped bar plot for average IT spending per 1000 people for 2015 and 2016
plt.figure(figsize=(12, 6))
plt.bar(x - bar_width/2, df['2015 IT Spend per Capita'], bar_width, label='2015', alpha=0.7, linewidth=2,color='green',edgecolor='black')
plt.bar(x + bar_width/2, df['2016 IT Spend per Capita'], bar_width, label='2016', color='red', alpha=0.7,linewidth=2, edgecolor='black'
)


plt.xlabel('Country')
plt.ylabel('IT Spend per person',fontsize=10,fontweight ='bold')
plt.title('Average IT Spend per person (2015 and 2016)')
plt.xticks(x, df['Country'], rotation=90, ha='right',fontsize=15,fontweight ='bold')
plt.yticks(fontsize=10,fontweight ='bold')


plt.legend()
plt.tight_layout()
plt.show()
df['average_it_spend'] = df[['2015 IT Spend per Capita', '2016 IT Spend per Capita']].mean(axis=1)
df['average_population'] = df[['2015 Populations (Millions)', '2016 Populations (Millions)']].mean(axis=1)
df
# Out:
#         Country 2015 Populations (Millions) 2015 GDP ($ Billions)  \
# 0     Australia                          24                  1349
# 1         China                        1371                 11065
# 2     Hong Kong                           7                   309
# 3         India                        1309                  2102
# 4     Indonesia                         258                   861
# 5         Japan                         127                  4395
# 6      Malaysia                          31                   296
# 7   New Zealand                           5                   178
# 8   Philippines                         102                   293
# 9     Singapore                           6                   304
# 10  South Korea                          51                  1383
# 11       Taiwan                          23                   526
# 12     Thailand                          69                   401
# 13      Vietnam                         NaN                   NaN
#
#    2015 IT Spend ($ Millions) 2016 Populations (Millions)  \
# 0                       82651                          24
# 1                      211400                        1379
# 2                       18154                           7
# 3                       68850                        1324
# 4                        8571                         261
# 5                      609000                         127
# 6                       14872                          31
# 7                       10527                           5
# 8                        4063                         103
# 9                       25096                           6
# 10                        NaN                          51
# 11                      20411                          24
# 12                        NaN                          69
# 13                        NaN                          95
#
#    2016 GDP ($ Billions) 2016 IT Spend ($ Millions) 2015 IT Spend per Capita  \
# 0                   1208                      84800                     3465
# 1                  11191                     226400                      154
# 2                    321                      18572                     2490
# 3                   2274                      67740                       53
# 4                    932                       9600                       33
# 5                   4949                     627000                     4790
# 6                    297                      15794                      484
# 7                    189                      10790                     2291
# 8                    305                       4400                       40
# 9                    310                      26200                     4534
# 10                  1415                        NaN                      NaN
# 11                   531                      20840                      869
# 12                   412                        NaN                      NaN
# 13                   205                        NaN                      NaN
#
#    2016 IT Spend per Capita  average_it_spend  average_population
# 0                      3503              3484                  24
# 1                       164               159                1375
# 2                      2531              2511                   7
# 3                        51                52                1317
# 4                        37                35                 260
# 5                      4937              4864                 127
# 6                       506               495                  31
# 7                      2299              2295                   5
# 8                        43                41                 103
# 9                      4672              4603                   6
# 10                      NaN               NaN                  51
# 11                      885               877                  24
# 12                      NaN               NaN                  69
# 13                      NaN               NaN                  95

# %% [markdown]
# ### its intersting to see how much money do we spend based on the size of the country, do we spend a lott on a tiny country? does the invesment returns itself?:

# %% [markdown]
# ### money spent vs country size:

# %%
plt.figure(figsize=(12, 8))
dot_size = df['average_population']
color_values = df['average_it_spend']

# Create the scatter plot
scatter = plt.scatter(df['average_it_spend'], df['average_population'], s=dot_size, c=color_values, cmap='viridis', alpha=0.7)

# Add color bar to show the relationship between color and IT spend
cbar = plt.colorbar(scatter)
cbar.set_label('Average IT Spend')

# Annotate the plot with country names (bold and larger font)
for i, country in enumerate(df['Country']):
    plt.annotate(country, (df['average_it_spend'][i], df['average_population'][i]),
                 fontsize=10, fontweight='bold', alpha=0.7)

# Add labels and a title
plt.xlabel('Average IT Spend')
plt.ylabel('Average Population Millions')
plt.title('Average IT Spend vs. Average Population by Country')


# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()
df
# Out:
#         Country 2015 Populations (Millions) 2015 GDP ($ Billions)  \
# 0     Australia                          24                  1349
# 1         China                        1371                 11065
# 2     Hong Kong                           7                   309
# 3         India                        1309                  2102
# 4     Indonesia                         258                   861
# 5         Japan                         127                  4395
# 6      Malaysia                          31                   296
# 7   New Zealand                           5                   178
# 8   Philippines                         102                   293
# 9     Singapore                           6                   304
# 10  South Korea                          51                  1383
# 11       Taiwan                          23                   526
# 12     Thailand                          69                   401
# 13      Vietnam                         NaN                   NaN
#
#    2015 IT Spend ($ Millions) 2016 Populations (Millions)  \
# 0                       82651                          24
# 1                      211400                        1379
# 2                       18154                           7
# 3                       68850                        1324
# 4                        8571                         261
# 5                      609000                         127
# 6                       14872                          31
# 7                       10527                           5
# 8                        4063                         103
# 9                       25096                           6
# 10                        NaN                          51
# 11                      20411                          24
# 12                        NaN                          69
# 13                        NaN                          95
#
#    2016 GDP ($ Billions) 2016 IT Spend ($ Millions) 2015 IT Spend per Capita  \
# 0                   1208                      84800                     3465
# 1                  11191                     226400                      154
# 2                    321                      18572                     2490
# 3                   2274                      67740                       53
# 4                    932                       9600                       33
# 5                   4949                     627000                     4790
# 6                    297                      15794                      484
# 7                    189                      10790                     2291
# 8                    305                       4400                       40
# 9                    310                      26200                     4534
# 10                  1415                        NaN                      NaN
# 11                   531                      20840                      869
# 12                   412                        NaN                      NaN
# 13                   205                        NaN                      NaN
#
#    2016 IT Spend per Capita  average_it_spend  average_population
# 0                      3503              3484                  24
# 1                       164               159                1375
# 2                      2531              2511                   7
# 3                        51                52                1317
# 4                        37                35                 260
# 5                      4937              4864                 127
# 6                       506               495                  31
# 7                      2299              2295                   5
# 8                        43                41                 103
# 9                      4672              4603                   6
# 10                      NaN               NaN                  51
# 11                      885               877                  24
# 12                      NaN               NaN                  69
# 13                      NaN               NaN                  95

# %%
top3
# Out:
#   Channel Country  Q1-15    Q2-15    Q3-15    Q4-15   Q1-16    Q2-16   \
# 0       Australia 9126852 15628393 15505620 10490510 8297715 19008654
# 1           India 7374906  7512036  7179319  6634408 7923857  7945253
# 2           Japan 5442290  6286630  5515913  5376888 7438962  8775265
#
#     Q3-16    Q4-16
# 0 13630455 13840018
# 1  8009614 10873627
# 2  9120352  8344142

# %% [markdown]
# #### we can clearly see that two out of three of the countries that have highest income spend the most money per person in population, hence will recomend to invest in this aspect

# %% [markdown]
# #### look for when sales arent profitable:

# %%
sales.fillna(0, inplace=True)
sales['sum_row']=sales.sum(axis=1)

negetive=sales.loc[(sales['sum_row']<0)]
negetive
# Out:
#      Channel Country                     Sold to Name      Product Type  \
# 39         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 43         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 44         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 53         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 99         Australia      ARROW ECS AUSTRALIA PTY LTD  2.5 SMARTDEFENSE
# ...              ...                              ...               ...
# 7329         Vietnam                       MISOFT JSC        3. SUPPORT
# 7335         Vietnam                       MISOFT JSC  7. SA AGREEMENTS
# 7458         Vietnam  M-SECURITY TECHNOLOGY INDOCHINA  2.5 SMARTDEFENSE
# 7462         Vietnam  M-SECURITY TECHNOLOGY INDOCHINA        3. SUPPORT
# 7465         Vietnam  M-SECURITY TECHNOLOGY INDOCHINA  7. SA AGREEMENTS
#
#                    Product Sub-type    Product Family Material Classificat  \
# 39           1.25 Stand Alone (+HW)      IP APPLIANCE            APPLIANCE
# 43           1.25 Stand Alone (+HW)        UTM-1 EDGE            APPLIANCE
# 44           1.25 Stand Alone (+HW)             VSX-1            APPLIANCE
# 53    1.31 Stand Alone + (ADSL-WIR)             SAFE@            APPLIANCE
# 99          9.91 Blades credit fees  SMDF CREDIT FEES             SOFTWARE
# ...                             ...               ...                  ...
# 7329             17 CES CREDIT FEES               CES             SOFTWARE
# 7335          7.1 REBATE AGREEMENTS     PRODUCT-OTHER                    #
# 7458        9.91 Blades credit fees  SMDF CREDIT FEES             SOFTWARE
# 7462             17 CES CREDIT FEES               CES             SOFTWARE
# 7465          7.1 REBATE AGREEMENTS     PRODUCT-OTHER                    #
#
#       Q1-15 Booked Amount  Q2-15 Booked Amount  Q3-15 Booked Amount  \
# 39                      0               -17980                    0
# 43                  -1356                    0                    0
# 44                      0                    0                    0
# 53                      0                  -92                    0
# 99                 -44390              -170880              -110297
# ...                   ...                  ...                  ...
# 7329                  -41                    0                  -32
# 7335                    0                    0                    0
# 7458                -2083                   -9                -1947
# 7462                    0                  -41                  -57
# 7465                    0                    0                    0
#
#       Q4-15 Booked Amount  Q1-16 Booked Amount  Q2-16 Booked Amount  \
# 39                      0                    0                    0
# 43                      0                    0                    0
# 44                      0               -16928                    0
# 53                      0                    0                    0
# 99                -118562               -96220              -173309
# ...                   ...                  ...                  ...
# 7329                 -303                    0                -3739
# 7335                    0               -19724                    0
# 7458                  -92                    0                    0
# 7462                    0                    0                -4520
# 7465                    0                    0                    0
#
#       Q3-16 Booked Amount  Q4-16 Booked Amount  sum_row
# 39                      0                    0   -17980
# 43                      0                    0    -1356
# 44                      0                    0   -16928
# 53                      0                    0      -92
# 99                -160693              -276367 -1150718
# ...                   ...                  ...      ...
# 7329                    0                -2454    -6569
# 7335                -7000                    0   -26724
# 7458                    0                -1341    -5472
# 7462                -1080                -1135    -6833
# 7465                -5000                    0    -5000
#
# [283 rows x 15 columns]

# %% [markdown]
# #### there are 283 transactions when Checkpoint lost money in, its a good idea to spend more time to investigate these transactions and check what may have caused this

# %% [markdown]
# ###

# %%
negetive
# Out:
#      Channel Country                     Sold to Name      Product Type  \
# 39         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 43         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 44         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 53         Australia      ARROW ECS AUSTRALIA PTY LTD        1. PRODUCT
# 99         Australia      ARROW ECS AUSTRALIA PTY LTD  2.5 SMARTDEFENSE
# ...              ...                              ...               ...
# 7329         Vietnam                       MISOFT JSC        3. SUPPORT
# 7335         Vietnam                       MISOFT JSC  7. SA AGREEMENTS
# 7458         Vietnam  M-SECURITY TECHNOLOGY INDOCHINA  2.5 SMARTDEFENSE
# 7462         Vietnam  M-SECURITY TECHNOLOGY INDOCHINA        3. SUPPORT
# 7465         Vietnam  M-SECURITY TECHNOLOGY INDOCHINA  7. SA AGREEMENTS
#
#                    Product Sub-type    Product Family Material Classificat  \
# 39           1.25 Stand Alone (+HW)      IP APPLIANCE            APPLIANCE
# 43           1.25 Stand Alone (+HW)        UTM-1 EDGE            APPLIANCE
# 44           1.25 Stand Alone (+HW)             VSX-1            APPLIANCE
# 53    1.31 Stand Alone + (ADSL-WIR)             SAFE@            APPLIANCE
# 99          9.91 Blades credit fees  SMDF CREDIT FEES             SOFTWARE
# ...                             ...               ...                  ...
# 7329             17 CES CREDIT FEES               CES             SOFTWARE
# 7335          7.1 REBATE AGREEMENTS     PRODUCT-OTHER                    #
# 7458        9.91 Blades credit fees  SMDF CREDIT FEES             SOFTWARE
# 7462             17 CES CREDIT FEES               CES             SOFTWARE
# 7465          7.1 REBATE AGREEMENTS     PRODUCT-OTHER                    #
#
#       Q1-15 Booked Amount  Q2-15 Booked Amount  Q3-15 Booked Amount  \
# 39                      0               -17980                    0
# 43                  -1356                    0                    0
# 44                      0                    0                    0
# 53                      0                  -92                    0
# 99                 -44390              -170880              -110297
# ...                   ...                  ...                  ...
# 7329                  -41                    0                  -32
# 7335                    0                    0                    0
# 7458                -2083                   -9                -1947
# 7462                    0                  -41                  -57
# 7465                    0                    0                    0
#
#       Q4-15 Booked Amount  Q1-16 Booked Amount  Q2-16 Booked Amount  \
# 39                      0                    0                    0
# 43                      0                    0                    0
# 44                      0               -16928                    0
# 53                      0                    0                    0
# 99                -118562               -96220              -173309
# ...                   ...                  ...                  ...
# 7329                 -303                    0                -3739
# 7335                    0               -19724                    0
# 7458                  -92                    0                    0
# 7462                    0                    0                -4520
# 7465                    0                    0                    0
#
#       Q3-16 Booked Amount  Q4-16 Booked Amount  sum_row
# 39                      0                    0   -17980
# 43                      0                    0    -1356
# 44                      0                    0   -16928
# 53                      0                    0      -92
# 99                -160693              -276367 -1150718
# ...                   ...                  ...      ...
# 7329                    0                -2454    -6569
# 7335                -7000                    0   -26724
# 7458                    0                -1341    -5472
# 7462                -1080                -1135    -6833
# 7465                -5000                    0    -5000
#
# [283 rows x 15 columns]

# %%
# Sum of 2015 booked amounts
sum_2015 = negetive[['Q1-15 Booked Amount', 'Q2-15 Booked Amount', 'Q3-15 Booked Amount', 'Q4-15 Booked Amount']].sum().sum()

# Sum of 2016 booked amounts
sum_2016 = negetive[['Q1-16 Booked Amount', 'Q2-16 Booked Amount', 'Q3-16 Booked Amount', 'Q4-16 Booked Amount']].sum().sum()

sum_2015, sum_2016
# Out:
# (-5902449.0, -6011535.0)

# %% [markdown]
# ###

# %% [markdown]
# ### loss of money by country and product type

# %%
count_negative = negetive.groupby(['Channel Country', 'Product Type'])['sum_row'].sum().reset_index()
count_negative=count_negative.head(60).sort_values(by='sum_row', ascending=True)
count_negative.reset_index(drop=True)
# Out:
#    Channel Country          Product Type  sum_row
# 0        Australia            3. SUPPORT -3309254
# 1        Australia      2.5 SMARTDEFENSE -1769028
# 2            India            3. SUPPORT -1471579
# 3        Singapore            3. SUPPORT  -880957
# 4      New Zealand            3. SUPPORT  -611599
# 5      New Zealand      2.5 SMARTDEFENSE  -364244
# 6        Hong Kong            3. SUPPORT  -270578
# 7        Australia            1. PRODUCT  -253463
# 8            China            1. PRODUCT  -239749
# 9            India            1. PRODUCT  -230971
# 10           China            3. SUPPORT  -208535
# 11           India      2.5 SMARTDEFENSE  -208400
# 12       Hong Kong      2.5 SMARTDEFENSE  -187142
# 13          Taiwan            1. PRODUCT  -180150
# 14       Singapore      2.5 SMARTDEFENSE  -144533
# 15           Japan            3. SUPPORT  -128826
# 16     South Korea            3. SUPPORT   -79559
# 17           China      2.5 SMARTDEFENSE   -77241
# 18     Philippines            1. PRODUCT   -76500
# 19           China  6. PROFESSIONAL SERV   -68850
# 20       Hong Kong            1. PRODUCT   -64154
# 21       Indonesia            3. SUPPORT   -55964
# 22          Taiwan      2.5 SMARTDEFENSE   -47037
# 23        Malaysia            3. SUPPORT   -46172
# 24       Australia      7. SA AGREEMENTS   -44988
# 25           Japan      2.5 SMARTDEFENSE   -43912
# 26           China      7. SA AGREEMENTS   -41391
# 27           India      7. SA AGREEMENTS   -39048
# 28     Philippines            3. SUPPORT   -34002
# 29        Malaysia      2.5 SMARTDEFENSE   -33716
# 30     South Korea            1. PRODUCT   -33222
# 31       Singapore      7. SA AGREEMENTS   -31597
# 32       Indonesia      7. SA AGREEMENTS   -28063
# 33     Philippines      2.5 SMARTDEFENSE   -28045
# 34       Hong Kong      7. SA AGREEMENTS   -25918
# 35       Indonesia      2.5 SMARTDEFENSE   -24815
# 36       Singapore    9.5 SERVICE BUNDLE   -19957
# 37       Singapore            1. PRODUCT   -19935
# 38           Japan      7. SA AGREEMENTS   -16609
# 39     Philippines      7. SA AGREEMENTS   -13952
# 40     Philippines     9.6 SERVICE BLADE   -12676
# 41       Hong Kong    9.5 SERVICE BUNDLE   -11130
# 42        Malaysia            1. PRODUCT   -10509
# 43     South Korea      2.5 SMARTDEFENSE   -10214
# 44       Australia     3.6 SUPPORT OTHER    -4560
# 45       Australia     9.6 SERVICE BLADE    -4349
# 46           India     9.6 SERVICE BLADE    -4040
# 47       Singapore          5. MARKETING    -3953
# 48       Australia    9.5 SERVICE BUNDLE    -3532
# 49       Hong Kong          5. MARKETING    -3386
# 50     New Zealand            1. PRODUCT    -3349
# 51           Japan    9.5 SERVICE BUNDLE    -3341
# 52       Indonesia            1. PRODUCT    -2400
# 53       Indonesia    9.5 SERVICE BUNDLE    -1449
# 54       Australia          5. MARKETING    -1290
# 55       Hong Kong     9.6 SERVICE BLADE    -1019
# 56     Philippines          5. MARKETING     -752
# 57           India          5. MARKETING     -550
# 58           India    9.5 SERVICE BUNDLE     -195
# 59           Japan     9.6 SERVICE BLADE     -178

# %% [markdown]
# #### out of 5 top losing transactions 4 of them were by support products

# %%
negetive['sum_row'].sum()
# Out:
# -11913984.0

# %% [markdown]
# ### total lost of 11913984.0 dollars

# %% [markdown]
# ####  i am motivated to understand how many transactions each country comeeted in order to maybe reaveal some further information (for example maybe a country comeeted a small amount of transactions and made allot of money from them- that would be extremly interestin)

# %% [markdown]
# ###  total transactions per country:

# %%
count_table=sales[['Channel Country']]
per_transaction = count_table.groupby('Channel Country').size().reset_index(name='Count of transactions 2015-2016')
per_transaction
# Out:
#    Channel Country  Count of transactions 2015-2016
# 0        Australia                              718
# 1            China                              606
# 2        Hong Kong                              613
# 3            India                             1282
# 4        Indonesia                              379
# 5            Japan                              636
# 6         Malaysia                              357
# 7      New Zealand                              396
# 8      Philippines                              375
# 9        Singapore                              633
# 10     South Korea                              337
# 11          Taiwan                              517
# 12        Thailand                              426
# 13         Vietnam                              249

# %% [markdown]
# ###  create aggregate table called per_transaction, merge with booked amount data and calcualte booked amount average:

# %%
result['total booked amount 2015 2016']=result.sum(axis=1)
a=per_transaction
b=result[['Country','total booked amount 2015 2016']]
a.rename(columns={'Channel Country': 'Country'}, inplace=True)
per_transaction = pd.merge(a,b,on =['Country'],how ="left")
per_transaction['booked amount per transaction']=per_transaction['total booked amount 2015 2016']/per_transaction['Count of transactions 2015-2016']
per_transaction
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 1         China                              606
# 2     Hong Kong                              613
# 3         India                             1282
# 4     Indonesia                              379
# 5         Japan                              636
# 6      Malaysia                              357
# 7   New Zealand                              396
# 8   Philippines                              375
# 9     Singapore                              633
# 10  South Korea                              337
# 11       Taiwan                              517
# 12     Thailand                              426
# 13      Vietnam                              249
#
#     total booked amount 2015 2016  booked amount per transaction
# 0                       118719244                         165347
# 1                        30171509                          49788
# 2                        31977357                          52165
# 3                        71384648                          55682
# 4                        15850180                          41821
# 5                        63337997                          99588
# 6                         8232396                          23060
# 7                        23735060                          59937
# 8                        10590651                          28242
# 9                        58687158                          92713
# 10                       11802002                          35021
# 11                       11415897                          22081
# 12                       11282976                          26486
# 13                        8160361                          32773

# %% [markdown]
# ###  calculate total assigned per country:

# %%
columns_to_sum=[]
for quarter in quarters:
    Booked_col = f'{quarter} Assigned'
    columns_to_sum.append(Booked_col)
    
country_column = 'Country'  # Replace with your actual country column name
columns_to_include = [country_column] + columns_to_sum

# Creating the new DataFrame
expens_agg = merge_roi[columns_to_include]
expens_agg['total assigned 2015 2016']=expens_agg.sum(axis=1)
expens_agg=expens_agg[['Country','total assigned 2015 2016']]
expens_agg
# Out:
#         Country  total assigned 2015 2016
# 0     Australia                  33713223
# 1         China                  10849370
# 2     Hong Kong                   7947816
# 3         India                  10269111
# 4     Indonesia                    765083
# 5         Japan                  16811232
# 6      Malaysia                     80504
# 7   New Zealand                   1879953
# 8   Philippines                    123312
# 9     Singapore                  19228933
# 10       Taiwan                   2941801
# 11     Thailand                    146550
# 12      Vietnam                    115264

# %% [markdown]
# ###  calcualate total planned per country:

# %%
#new test:
columns_to_sum=[]
for quarter in quarters:
    Booked_col = f'{quarter} Plan'
    columns_to_sum.append(Booked_col)
    
country_column = 'Country'  # Replace with your actual country column name
columns_to_include = [country_column] + columns_to_sum

# Creating the new DataFrame
planned_agg = Assigned_vs_planned[columns_to_include]
planned_agg['total planned 2015 2016']=planned_agg.sum(axis=1)
planned_agg=planned_agg[['Country','total planned 2015 2016']]
planned_agg
# Out:
#         Country  total planned 2015 2016
# 0     Australia                 40968180
# 1         China                 11184885
# 2     Hong Kong                  9757614
# 3         India                  8832658
# 4     Indonesia                   831731
# 5         Japan                 16527888
# 6         Korea                  3603499
# 7      Malaysia                        0
# 8   New Zealand                        0
# 9   Philippines                        0
# 10    Singapore                 14629638
# 11       Taiwan                  3022156
# 12     Thailand                        0
# 13      Vietnam                        0

# %% [markdown]
# ###

# %% [markdown]
# ###  merge to per_transaction table:

# %%
per_transaction=pd.merge(per_transaction,expens_agg,on =['Country'],how ="right")
per_transaction= pd.merge(per_transaction,planned_agg,on =['Country'],how ="right")
per_transaction
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 1         China                              606
# 2     Hong Kong                              613
# 3         India                             1282
# 4     Indonesia                              379
# 5         Japan                              636
# 6         Korea                              NaN
# 7      Malaysia                              357
# 8   New Zealand                              396
# 9   Philippines                              375
# 10    Singapore                              633
# 11       Taiwan                              517
# 12     Thailand                              426
# 13      Vietnam                              249
#
#     total booked amount 2015 2016  booked amount per transaction  \
# 0                       118719244                         165347
# 1                        30171509                          49788
# 2                        31977357                          52165
# 3                        71384648                          55682
# 4                        15850180                          41821
# 5                        63337997                          99588
# 6                             NaN                            NaN
# 7                         8232396                          23060
# 8                        23735060                          59937
# 9                        10590651                          28242
# 10                       58687158                          92713
# 11                       11415897                          22081
# 12                       11282976                          26486
# 13                        8160361                          32773
#
#     total assigned 2015 2016  total planned 2015 2016
# 0                   33713223                 40968180
# 1                   10849370                 11184885
# 2                    7947816                  9757614
# 3                   10269111                  8832658
# 4                     765083                   831731
# 5                   16811232                 16527888
# 6                        NaN                  3603499
# 7                      80504                        0
# 8                    1879953                        0
# 9                     123312                        0
# 10                  19228933                 14629638
# 11                   2941801                  3022156
# 12                    146550                        0
# 13                    115264                        0

# %% [markdown]
# ###  calculate average head count per country and merge to per_transaction table:

# %%
for col in Head_count.columns[1:]:
    Head_count[col] = pd.to_numeric(Head_count[col], errors='coerce')
Head_count['average employees']=Head_count.mean(axis=1)
Head_count.rename(columns={'Employee Country': 'Country'}, inplace=True)
Head_count_for_merge=Head_count[['Country','average employees']]
per_transaction = pd.merge(per_transaction,Head_count_for_merge,on =['Country'],how ="right")
per_transaction
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 1         China                              606
# 2     Hong Kong                              613
# 3         India                             1282
# 4     Indonesia                              379
# 5         Japan                              636
# 6      Malaysia                              357
# 7   New Zealand                              396
# 8   Philippines                              375
# 9     Singapore                              633
# 10  South Korea                              NaN
# 11       Taiwan                              517
# 12     Thailand                              426
# 13      Vietnam                              249
# 14   APAC Total                              NaN
#
#     total booked amount 2015 2016  booked amount per transaction  \
# 0                       118719244                         165347
# 1                        30171509                          49788
# 2                        31977357                          52165
# 3                        71384648                          55682
# 4                        15850180                          41821
# 5                        63337997                          99588
# 6                         8232396                          23060
# 7                        23735060                          59937
# 8                        10590651                          28242
# 9                        58687158                          92713
# 10                            NaN                            NaN
# 11                       11415897                          22081
# 12                       11282976                          26486
# 13                        8160361                          32773
# 14                            NaN                            NaN
#
#     total assigned 2015 2016  total planned 2015 2016  average employees
# 0                   33713223                 40968180                 62
# 1                   10849370                 11184885                 38
# 2                    7947816                  9757614                 18
# 3                   10269111                  8832658                 43
# 4                     765083                   831731                  6
# 5                   16811232                 16527888                 37
# 6                      80504                        0                  3
# 7                    1879953                        0                  8
# 8                     123312                        0                  2
# 9                   19228933                 14629638                 42
# 10                       NaN                      NaN                 11
# 11                   2941801                  3022156                 11
# 12                    146550                        0                  4
# 13                    115264                        0                  3
# 14                       NaN                      NaN                287

# %% [markdown]
# ###  clean it spend data, and merge to per_transaction table:

# %%
for col in it_spend.columns[1:]:
    it_spend[col] = pd.to_numeric(it_spend[col], errors='coerce')
it_spend1=it_spend[['Country','2015 Populations (Millions)','2016 Populations (Millions)']]
it_spend2=it_spend[['Country','2015 GDP ($ Billions)','2016 GDP ($ Billions)']]
it_spend3=it_spend[['Country','2015 IT Spend ($ Millions)','2016 IT Spend per Capita']]

#_______________________________________________________________________________________________________________________________

it_spend1["average 2016 Populations (Millions) 2015-2016"]=it_spend1.mean(axis=1)
it_spend1=it_spend1[['Country','average 2016 Populations (Millions) 2015-2016']]

it_spend2["GDP ($ Billions) 2015-2016"]=it_spend2.mean(axis=1)
it_spend2=it_spend2[['Country','GDP ($ Billions) 2015-2016']]

it_spend3["IT Spend ($ Millions) 2015-2016"]=it_spend3.mean(axis=1)
it_spend3=it_spend3[['Country','IT Spend ($ Millions) 2015-2016']]

#_______________________________________________________________________________________________________________________________

per_transaction = pd.merge(per_transaction,it_spend1,on =['Country'],how ="right")
per_transaction = pd.merge(per_transaction,it_spend2,on =['Country'],how ="right")
per_transaction = pd.merge(per_transaction,it_spend3,on =['Country'],how ="right")
per_transaction
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 1         China                              606
# 2     Hong Kong                              613
# 3         India                             1282
# 4     Indonesia                              379
# 5         Japan                              636
# 6      Malaysia                              357
# 7   New Zealand                              396
# 8   Philippines                              375
# 9     Singapore                              633
# 10  South Korea                              NaN
# 11       Taiwan                              517
# 12     Thailand                              426
# 13      Vietnam                              249
#
#     total booked amount 2015 2016  booked amount per transaction  \
# 0                       118719244                         165347
# 1                        30171509                          49788
# 2                        31977357                          52165
# 3                        71384648                          55682
# 4                        15850180                          41821
# 5                        63337997                          99588
# 6                         8232396                          23060
# 7                        23735060                          59937
# 8                        10590651                          28242
# 9                        58687158                          92713
# 10                            NaN                            NaN
# 11                       11415897                          22081
# 12                       11282976                          26486
# 13                        8160361                          32773
#
#     total assigned 2015 2016  total planned 2015 2016  average employees  \
# 0                   33713223                 40968180                 62
# 1                   10849370                 11184885                 38
# 2                    7947816                  9757614                 18
# 3                   10269111                  8832658                 43
# 4                     765083                   831731                  6
# 5                   16811232                 16527888                 37
# 6                      80504                        0                  3
# 7                    1879953                        0                  8
# 8                     123312                        0                  2
# 9                   19228933                 14629638                 42
# 10                       NaN                      NaN                 11
# 11                   2941801                  3022156                 11
# 12                    146550                        0                  4
# 13                    115264                        0                  3
#
#     average 2016 Populations (Millions) 2015-2016  GDP ($ Billions) 2015-2016  \
# 0                                              24                        1279
# 1                                            1375                       11128
# 2                                               7                         315
# 3                                            1317                        2188
# 4                                             260                         897
# 5                                             127                        4672
# 6                                              31                         296
# 7                                               5                         183
# 8                                             103                         299
# 9                                               6                         307
# 10                                             51                        1399
# 11                                             24                         528
# 12                                             69                         407
# 13                                             95                         205
#
#     IT Spend ($ Millions) 2015-2016
# 0                             43077
# 1                            105782
# 2                             10343
# 3                             34451
# 4                              4304
# 5                            306969
# 6                              7689
# 7                              6413
# 8                              2053
# 9                             14884
# 10                              NaN
# 11                            10648
# 12                              NaN
# 13                              NaN

# %% [markdown]
# ###  clean table before visualizations:

# %%
one_na_mask = per_transaction.isna().sum(axis=1) == 1

# Fill these rows with 0
per_transaction.loc[one_na_mask] = per_transaction.loc[one_na_mask].fillna(0)

# Drop rows with more than one NA
per_transaction.dropna(thresh=len(per_transaction.columns) - 1, inplace=True)
per_transaction
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 1         China                              606
# 2     Hong Kong                              613
# 3         India                             1282
# 4     Indonesia                              379
# 5         Japan                              636
# 6      Malaysia                              357
# 7   New Zealand                              396
# 8   Philippines                              375
# 9     Singapore                              633
# 11       Taiwan                              517
# 12     Thailand                              426
# 13      Vietnam                              249
#
#     total booked amount 2015 2016  booked amount per transaction  \
# 0                       118719244                         165347
# 1                        30171509                          49788
# 2                        31977357                          52165
# 3                        71384648                          55682
# 4                        15850180                          41821
# 5                        63337997                          99588
# 6                         8232396                          23060
# 7                        23735060                          59937
# 8                        10590651                          28242
# 9                        58687158                          92713
# 11                       11415897                          22081
# 12                       11282976                          26486
# 13                        8160361                          32773
#
#     total assigned 2015 2016  total planned 2015 2016  average employees  \
# 0                   33713223                 40968180                 62
# 1                   10849370                 11184885                 38
# 2                    7947816                  9757614                 18
# 3                   10269111                  8832658                 43
# 4                     765083                   831731                  6
# 5                   16811232                 16527888                 37
# 6                      80504                        0                  3
# 7                    1879953                        0                  8
# 8                     123312                        0                  2
# 9                   19228933                 14629638                 42
# 11                   2941801                  3022156                 11
# 12                    146550                        0                  4
# 13                    115264                        0                  3
#
#     average 2016 Populations (Millions) 2015-2016  GDP ($ Billions) 2015-2016  \
# 0                                              24                        1279
# 1                                            1375                       11128
# 2                                               7                         315
# 3                                            1317                        2188
# 4                                             260                         897
# 5                                             127                        4672
# 6                                              31                         296
# 7                                               5                         183
# 8                                             103                         299
# 9                                               6                         307
# 11                                             24                         528
# 12                                             69                         407
# 13                                             95                         205
#
#     IT Spend ($ Millions) 2015-2016
# 0                             43077
# 1                            105782
# 2                             10343
# 3                             34451
# 4                              4304
# 5                            306969
# 6                              7689
# 7                              6413
# 8                              2053
# 9                             14884
# 11                            10648
# 12                                0
# 13                                0

# %% [markdown]
# ###  calcualte total ROI:

# %%
per_transaction['total roi']=per_transaction['total booked amount 2015 2016']/per_transaction['total assigned 2015 2016']*100
per_transaction
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 1         China                              606
# 2     Hong Kong                              613
# 3         India                             1282
# 4     Indonesia                              379
# 5         Japan                              636
# 6      Malaysia                              357
# 7   New Zealand                              396
# 8   Philippines                              375
# 9     Singapore                              633
# 11       Taiwan                              517
# 12     Thailand                              426
# 13      Vietnam                              249
#
#     total booked amount 2015 2016  booked amount per transaction  \
# 0                       118719244                         165347
# 1                        30171509                          49788
# 2                        31977357                          52165
# 3                        71384648                          55682
# 4                        15850180                          41821
# 5                        63337997                          99588
# 6                         8232396                          23060
# 7                        23735060                          59937
# 8                        10590651                          28242
# 9                        58687158                          92713
# 11                       11415897                          22081
# 12                       11282976                          26486
# 13                        8160361                          32773
#
#     total assigned 2015 2016  total planned 2015 2016  average employees  \
# 0                   33713223                 40968180                 62
# 1                   10849370                 11184885                 38
# 2                    7947816                  9757614                 18
# 3                   10269111                  8832658                 43
# 4                     765083                   831731                  6
# 5                   16811232                 16527888                 37
# 6                      80504                        0                  3
# 7                    1879953                        0                  8
# 8                     123312                        0                  2
# 9                   19228933                 14629638                 42
# 11                   2941801                  3022156                 11
# 12                    146550                        0                  4
# 13                    115264                        0                  3
#
#     average 2016 Populations (Millions) 2015-2016  GDP ($ Billions) 2015-2016  \
# 0                                              24                        1279
# 1                                            1375                       11128
# 2                                               7                         315
# 3                                            1317                        2188
# 4                                             260                         897
# 5                                             127                        4672
# 6                                              31                         296
# 7                                               5                         183
# 8                                             103                         299
# 9                                               6                         307
# 11                                             24                         528
# 12                                             69                         407
# 13                                             95                         205
#
#     IT Spend ($ Millions) 2015-2016  total roi
# 0                             43077        352
# 1                            105782        278
# 2                             10343        402
# 3                             34451        695
# 4                              4304       2072
# 5                            306969        377
# 6                              7689      10226
# 7                              6413       1263
# 8                              2053       8588
# 9                             14884        305
# 11                            10648        388
# 12                                0       7699
# 13                                0       7080

# %%
data=per_transaction

# %% [markdown]
# ###

# %% [markdown]
# ###  PLANNED VS ASSIGNED:

# %%
data.sort_values(by='total assigned 2015 2016', ascending=False, inplace=True)

plt.figure(figsize=(10, 6))

# Set the positions for the bars
positions = range(len(data['Country']))
bar_width = 0.4  # Width of the bars

# Plot 'total planned 2015 2016' in orange
plt.bar([p - bar_width/2 for p in positions], 
        data['total planned 2015 2016'], 
        width=bar_width, 
        label='Total Planned 2015-2016', 
        color='orange')

# Plot 'total assigned 2015 2016' in blue
plt.bar([p + bar_width/2 for p in positions], 
        data['total assigned 2015 2016'], 
        width=bar_width, 
        label='Total Assigned 2015-2016', 
        color='blue')

# Set the country names as x-ticks
plt.xticks(positions, data['Country'], rotation=45)

# Adding labels and title
plt.ylabel('Amount')
plt.title('Total Planned vs Total Assigned by Country')
plt.legend()
plt.gca().yaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ###  total booked amount by country:

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='total booked amount 2015 2016', data=data.sort_values(by='total booked amount 2015 2016', ascending=False),color='blue',alpha=0.9,linewidth=2, edgecolor='black')
plt.xticks(rotation=45)
plt.title('Total Booked Amount by Country')
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()

# %%
data
# Out:
#         Country  Count of transactions 2015-2016  \
# 0     Australia                              718
# 9     Singapore                              633
# 5         Japan                              636
# 1         China                              606
# 3         India                             1282
# 2     Hong Kong                              613
# 11       Taiwan                              517
# 7   New Zealand                              396
# 4     Indonesia                              379
# 12     Thailand                              426
# 8   Philippines                              375
# 13      Vietnam                              249
# 6      Malaysia                              357
#
#     total booked amount 2015 2016  booked amount per transaction  \
# 0                       118719244                         165347
# 9                        58687158                          92713
# 5                        63337997                          99588
# 1                        30171509                          49788
# 3                        71384648                          55682
# 2                        31977357                          52165
# 11                       11415897                          22081
# 7                        23735060                          59937
# 4                        15850180                          41821
# 12                       11282976                          26486
# 8                        10590651                          28242
# 13                        8160361                          32773
# 6                         8232396                          23060
#
#     total assigned 2015 2016  total planned 2015 2016  average employees  \
# 0                   33713223                 40968180                 62
# 9                   19228933                 14629638                 42
# 5                   16811232                 16527888                 37
# 1                   10849370                 11184885                 38
# 3                   10269111                  8832658                 43
# 2                    7947816                  9757614                 18
# 11                   2941801                  3022156                 11
# 7                    1879953                        0                  8
# 4                     765083                   831731                  6
# 12                    146550                        0                  4
# 8                     123312                        0                  2
# 13                    115264                        0                  3
# 6                      80504                        0                  3
#
#     average 2016 Populations (Millions) 2015-2016  GDP ($ Billions) 2015-2016  \
# 0                                              24                        1279
# 9                                               6                         307
# 5                                             127                        4672
# 1                                            1375                       11128
# 3                                            1317                        2188
# 2                                               7                         315
# 11                                             24                         528
# 7                                               5                         183
# 4                                             260                         897
# 12                                             69                         407
# 8                                             103                         299
# 13                                             95                         205
# 6                                              31                         296
#
#     IT Spend ($ Millions) 2015-2016  total roi
# 0                             43077        352
# 9                             14884        305
# 5                            306969        377
# 1                            105782        278
# 3                             34451        695
# 2                             10343        402
# 11                            10648        388
# 7                              6413       1263
# 4                              4304       2072
# 12                                0       7699
# 8                              2053       8588
# 13                                0       7080
# 6                              7689      10226

# %%
correlation = data['average employees'].corr(data['booked amount per transaction'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.8391315229323784

# %% [markdown]
# ###

# %% [markdown]
# ###  Booked Amount per Transaction as a Function of Average Employees:

# %%
plt.figure(figsize=(10, 6))

# Creating a scatter plot
plt.scatter(data['average employees'], data['booked amount per transaction'], color='green')

# Adding labels and title
plt.xlabel('Average Employees')
plt.ylabel('Booked Amount per Transaction',fontweight ='bold')
plt.title('Booked Amount per Transaction as a Function of Average Employees')

for index, row in data.iterrows():
    plt.annotate(row['Country'], (row['average employees'], row['booked amount per transaction']))

plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ###  Total ROI as a Function of GDP ($ Billions) 2015-2016:

# %%
plt.figure(figsize=(10, 6))

# Creating a scatter plot
plt.scatter(data['GDP ($ Billions) 2015-2016'], data['total roi'], color='blue')

# Adding labels and title
plt.xlabel('GDP ($ Billions) 2015-2016', fontweight='bold')
plt.ylabel('Total ROI', fontweight='bold')
plt.title('Total ROI as a Function of GDP ($ Billions) 2015-2016')

# Optionally, adding annotations for each point
for index, row in data.iterrows():
    plt.annotate(row['Country'], (row['GDP ($ Billions) 2015-2016'], row['total roi']))

plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ###  total booked amount as function of planned:

# %%
plt.figure(figsize=(10, 6))

# Creating a scatter plot
plt.scatter(data['total planned 2015 2016'], data['total booked amount 2015 2016'], color='blue')

# Adding labels and title
plt.xlabel('total planned 2015 2016', fontweight='bold')
plt.ylabel('total booked amount 2015 2016', fontweight='bold')
#plt.title('Total ROI as a Function of GDP ($ Billions) 2015-2016')

# Optionally, adding annotations for each point
for index, row in data.iterrows():
    plt.annotate(row['Country'], (row['total planned 2015 2016'], row['total booked amount 2015 2016']))

plt.show()
